# %% [markdown]
# <!-- Batching files -->

# %% [markdown]
# importing functions from the python project folder

# %%
from module import *

# %% [markdown]
# # Batching carrier files

# %%
# ---- EDIT THESE LINES ----------
# changing working directory to the client folder
os.chdir('/Users/noahwebb/Python/Carrier_File_Pipeline/TrueClient_Carrier_Files_py')
carrier = "VisionSavings"
# ------------------------------


# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)


# storing variables from config.json file 
file_input_path   = config[carrier]['file_input_path']
file_name_pattern = config[carrier]['file_name_pattern']
date_start_regx   = config[carrier]['date_start_regx']
date_length       = config[carrier]['date_length']
date_format       = config[carrier]['date_format']
output_header      = config['output']['output_header']

batch, file_name_pattern, files_start_dt, files_end_dt = concat_carrier(carrier, file_input_path, file_name_pattern, date_start_regx, date_length, date_format)
# Out:
# Listing files from directory [/Users/noahwebb/Python/Carrier_File_Pipeline/carrier_etl_test/carrier_file_input] ...
# reading file [VisionSavings_FSA_TrueClient_20230127.txt]...
# reading file [VisionSavings_FSA_TrueClient_20230227.txt]...
# reading file [VisionSavings_FSA_TrueClient_20230327.txt]...
#
# files batched!

# %% [markdown]
# ### View a sample of the table

# %%
print(f"filename pattern: {file_name_pattern}")
print(f"filename start date: {files_start_dt}")
print(f"filename end date: {files_end_dt}")

# selcting the first 100 rows
batch_head = batch.head(50)
batch_head
# Out:
# filename pattern: VisionSavings_FSA_TrueClient_
# filename start date: 2023-03-27
# filename end date: 2023-01-27
#            0          1            2        3  4         5            6  \
# 0  111724631  123456789  O'Furniture    Patty  L  19720606  O'Furniture
# 1  111724631  112233445       Chovey     Anne     19760926       Chovey
# 2  111724631  999999999         Nutt    Hazel  K  19701026         Nutt
# 3  111724631  900000000       Mellow   Marsha     19820411       Mellow
# 4  111724631  900000001          Yew    Olive     00010101          Yew
# 0  111724631  123456789        Feest  Laverne  K  19720606        Feest
# 1  111724631  112233445        Kutch  Tristan     19760926        Kutch
# 2  111724631  999999999       Brakus    Marty  D  19701026    Brakus II
# 3  111724631  900000000       Hudson    Haley  M  19820411       Hudson
# 4  111724631  900000001       Murphy  Godfrey     00010101       Murphy
# 0  111724631  123456789  O'Furniture    Patty  L  19720606  O'Furniture
# 1  111724631  112233445       Chovey     Anne     19760926       Chovey
# 2  111724631  999999999         Nutt    Hazel  K  19701026         Nutt
# 3  111724631  900000000       Mellow   Marsha     19820411       Mellow
# 4  111724631  900000001          Yew    Olive     00010101          Yew
#
#            7  8            9  ...      13                14  \
# 0      Patty  L  Vision-R-Us  ...  174.00   Ms Eye Care USA
# 1      Brian     Vision-R-Us  ...   40.90   EYEMART EXPRESS
# 2       Wall  A  Vision-R-Us  ...   33.50      Eye Care Inc
# 3     Mister  S  Vision-R-Us  ...    2.00  Wesley Eye House
# 4     Ivanna  S  Vision-R-Us  ...    3.00   Wal Mart Vision
# 0    Laverne  A  Vision-R-Us  ...  456.00   MR EYE MANFIELD
# 1      Kevin     Vision-R-Us  ...   50.10    EYE EXPOSITION
# 2      Marty  G  Vision-R-Us  ...   39.20      Eye Care Inc
# 3      Marie  F  Vision-R-Us  ...    5.00  Gerald's Eye Hut
# 4  Miss Lady  E  Vision-R-Us  ...   20.00  Fancy Vision Inc
# 0      Patty  L  Vision-R-Us  ...  174.00   Ms Eye Care USA
# 1      Brian     Vision-R-Us  ...   40.90   EYEMART EXPRESS
# 2       Wall  A  Vision-R-Us  ...   33.50      Eye Care Inc
# 3     Mister  S  Vision-R-Us  ...    2.00  Wesley Eye House
# 4     Ivanna  S  Vision-R-Us  ...    3.00   Wal Mart Vision
#
#                        15 16                    17  18      19  20 21  \
# 0           30 Johnson St                  Jackson  MS   55441  US
# 1  39 MCFARLAND BLVD EAST                   JUNEUA  AK   99801  US
# 2       395 Hargrove Rd E               Birmingham  AL   35944  US
# 3            6 Kevin Blvd     Good Purple Township  MO   64444  US
# 4             12th E Blvd                Northport  IL   55544  US
# 0            30 XAVIER RD                  BRAXTON  MS   64551  US
# 1     808 MAFIA BLVD EAST              JEFFERSMITH  CA   64813  US
# 2       1654 HAROLDPORT E                  VERMONT  MI   16458  US
# 3            6 JASON Blvd            ST JOSEPHTOWN  MO  644881  US
# 4         10 Lordway Blvd               Huntington  MA   31548  US
# 0           30 Johnson St                  Jackson  MS   55441  US
# 1  39 MCFARLAND BLVD EAST                   JUNEUA  AK   99801  US
# 2       395 Hargrove Rd E               Birmingham  AL   35944  US
# 3            6 Kevin Blvd     Good Purple Township  MO   64444  US
# 4             12th E Blvd                Northport  IL   55544  US
#
#                                    FILE_NAME
# 0  VisionSavings_FSA_TrueClient_20230127.txt
# 1  VisionSavings_FSA_TrueClient_20230127.txt
# 2  VisionSavings_FSA_TrueClient_20230127.txt
# 3  VisionSavings_FSA_TrueClient_20230127.txt
# 4  VisionSavings_FSA_TrueClient_20230127.txt
# 0  VisionSavings_FSA_TrueClient_20230227.txt
# 1  VisionSavings_FSA_TrueClient_20230227.txt
# 2  VisionSavings_FSA_TrueClient_20230227.txt
# 3  VisionSavings_FSA_TrueClient_20230227.txt
# 4  VisionSavings_FSA_TrueClient_20230227.txt
# 0  VisionSavings_FSA_TrueClient_20230327.txt
# 1  VisionSavings_FSA_TrueClient_20230327.txt
# 2  VisionSavings_FSA_TrueClient_20230327.txt
# 3  VisionSavings_FSA_TrueClient_20230327.txt
# 4  VisionSavings_FSA_TrueClient_20230327.txt
#
# [15 rows x 23 columns]

# %% [markdown]
# # Mapping the batch file to standard format

# %%
from module import *

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
output_header     = config['output']['output_header']
employer_code     = config['output']['employer_code']

map = map_TrueClient_VisionSavings(batch, output_header, employer_code)
map
# Out:
# mapping file to standard format...
#   EMPLOYER_CODE EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME  \
# 0        TC0001       111724631       123456789           O'Furniture
# 1        TC0001       111724631       112233445                Chovey
# 2        TC0001       111724631       999999999                  Nutt
# 3        TC0001       111724631       900000000                Mellow
# 4        TC0001       111724631       900000001                   Yew
# 0        TC0001       111724631       123456789                 Feest
# 1        TC0001       111724631       112233445                 Kutch
# 2        TC0001       111724631       999999999                Brakus
# 3        TC0001       111724631       900000000                Hudson
# 4        TC0001       111724631       900000001                Murphy
# 0        TC0001       111724631       123456789           O'Furniture
# 1        TC0001       111724631       112233445                Chovey
# 2        TC0001       111724631       999999999                  Nutt
# 3        TC0001       111724631       900000000                Mellow
# 4        TC0001       111724631       900000001                   Yew
#
#   PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL PARTICIPANT_DATE_OF_BIRTH  \
# 0                  Patty                          L                  19720606
# 1                   Anne                                             19760926
# 2                  Hazel                          K                  19701026
# 3                 Marsha                                             19820411
# 4                  Olive                                             00010101
# 0                Laverne                          K                  19720606
# 1                Tristan                                             19760926
# 2                  Marty                          D                  19701026
# 3                  Haley                          M                  19820411
# 4                Godfrey                                             00010101
# 0                  Patty                          L                  19720606
# 1                   Anne                                             19760926
# 2                  Hazel                          K                  19701026
# 3                 Marsha                                             19820411
# 4                  Olive                                             00010101
#
#   PATIENT_LAST_NAME PATIENT_FIRST_NAME PATIENT_MIDDLE_INITIAL  ...  \
# 0       O'Furniture              Patty                      L  ...
# 1            Chovey              Brian                         ...
# 2              Nutt               Wall                      A  ...
# 3            Mellow             Mister                      S  ...
# 4               Yew             Ivanna                      S  ...
# 0             Feest            Laverne                      A  ...
# 1             Kutch              Kevin                         ...
# 2         Brakus II              Marty                      G  ...
# 3            Hudson              Marie                      F  ...
# 4            Murphy          Miss Lady                      E  ...
# 0       O'Furniture              Patty                      L  ...
# 1            Chovey              Brian                         ...
# 2              Nutt               Wall                      A  ...
# 3            Mellow             Mister                      S  ...
# 4               Yew             Ivanna                      S  ...
#
#       PROVIDER_NAME       PROVIDER_ADDRESS1 PROVIDER_ADDRESS2  \
# 0   Ms Eye Care USA           30 Johnson St
# 1   EYEMART EXPRESS  39 MCFARLAND BLVD EAST
# 2      Eye Care Inc       395 Hargrove Rd E
# 3  Wesley Eye House            6 Kevin Blvd
# 4   Wal Mart Vision             12th E Blvd
# 0   MR EYE MANFIELD            30 XAVIER RD
# 1    EYE EXPOSITION     808 MAFIA BLVD EAST
# 2      Eye Care Inc       1654 HAROLDPORT E
# 3  Gerald's Eye Hut            6 JASON Blvd
# 4  Fancy Vision Inc         10 Lordway Blvd
# 0   Ms Eye Care USA           30 Johnson St
# 1   EYEMART EXPRESS  39 MCFARLAND BLVD EAST
# 2      Eye Care Inc       395 Hargrove Rd E
# 3  Wesley Eye House            6 Kevin Blvd
# 4   Wal Mart Vision             12th E Blvd
#
#           PROVIDER_CITY  PROVIDER_STATE PROVIDER_ZIP PROVIDER_COUNTRY  \
# 0               Jackson              MS        55441               US
# 1                JUNEUA              AK        99801               US
# 2            Birmingham              AL        35944               US
# 3  Good Purple Township              MO        64444               US
# 4             Northport              IL        55544               US
# 0               BRAXTON              MS        64551               US
# 1           JEFFERSMITH              CA        64813               US
# 2               VERMONT              MI        16458               US
# 3         ST JOSEPHTOWN              MO       644881               US
# 4            Huntington              MA        31548               US
# 0               Jackson              MS        55441               US
# 1                JUNEUA              AK        99801               US
# 2            Birmingham              AL        35944               US
# 3  Good Purple Township              MO        64444               US
# 4             Northport              IL        55544               US
#
#   CLAIM_TYPE                                  FILE_NAME EXPENSE_CATEGORY
# 0             VisionSavings_FSA_TrueClient_20230127.txt           vision
# 1             VisionSavings_FSA_TrueClient_20230127.txt           vision
# 2             VisionSavings_FSA_TrueClient_20230127.txt           vision
# 3             VisionSavings_FSA_TrueClient_20230127.txt           vision
# 4             VisionSavings_FSA_TrueClient_20230127.txt           vision
# 0             VisionSavings_FSA_TrueClient_20230227.txt           vision
# 1             VisionSavings_FSA_TrueClient_20230227.txt           vision
# 2             VisionSavings_FSA_TrueClient_20230227.txt           vision
# 3             VisionSavings_FSA_TrueClient_20230227.txt           vision
# 4             VisionSavings_FSA_TrueClient_20230227.txt           vision
# 0             VisionSavings_FSA_TrueClient_20230327.txt           vision
# 1             VisionSavings_FSA_TrueClient_20230327.txt           vision
# 2             VisionSavings_FSA_TrueClient_20230327.txt           vision
# 3             VisionSavings_FSA_TrueClient_20230327.txt           vision
# 4             VisionSavings_FSA_TrueClient_20230327.txt           vision
#
# [15 rows x 25 columns]

# %% [markdown]
# # Batching, mapping, and writing the file to the output directory (end-to-end process)

# %%
import os

from module import concat_and_map

map, fname = concat_and_map('VisionSavings')
# Out:
# Listing files from directory [/Users/noahwebb/Python/Carrier_File_Pipeline/carrier_etl_test/carrier_file_input] ...
# reading file [VisionSavings_FSA_TrueClient_20230127.txt]...
# reading file [VisionSavings_FSA_TrueClient_20230227.txt]...
# reading file [VisionSavings_FSA_TrueClient_20230327.txt]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [TC0001_VisionSavings_mapped_2023-03-27_to_2023-01-27.csv] to directory:
# [/Users/noahwebb/Python/Carrier_File_Pipeline/carrier_etl_test/carrier_file_output]...
#
#
# Done!
