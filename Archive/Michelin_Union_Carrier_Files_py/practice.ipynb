# %%
"""
Testing a multi-line comment

Test 1 2 3 
"""
# Out:
# '\nTesting a multi-line comment\n\nTest 1 2 3 \n\n'

# %%
import os

path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_list = os.listdir(path)

file_list
# Out:
# ['BFG_OPTUM_CLAIMS_20230519.TXT',
#  'BFG_OPTUM_CLAIMS_20230222 (1).TXT',
#  'BFG_OPTUM_CLAIMS_20230222.TXT',
#  'BFG_OPTUM_CLAIMS_20230224.TXT',
#  'BFG_OPTUM_CLAIMS_20230303.TXT',
#  'BFG_OPTUM_CLAIMS_20230310.TXT',
#  'BFG_OPTUM_CLAIMS_20230324.TXT',
#  'BFG_OPTUM_CLAIMS_20230331.TXT',
#  'BFG_OPTUM_CLAIMS_20230407.TXT',
#  'BFG_OPTUM_CLAIMS_20230414.TXT',
#  'BFG_OPTUM_CLAIMS_20230317.TXT',
#  'BFG_OPTUM_CLAIMS_202304281.TXT',
#  'BFG_OPTUM_CLAIMS_20230526.TXT',
#  'BFG_OPTUM_CLAIMS_20230605.TXT',
#  'BFG_OPTUM_CLAIMS_20230609.TXT',
#  'BFG_OPTUM_CLAIMS_20230616.TXT',
#  'BFG_OPTUM_CLAIMS_20230428.TXT',
#  'BFG_OPTUM_CLAIMS_20230428_2.TXT',
#  'BFG_OPTUM_CLAIMS_20230512.TXT',
#  'Combined Files',
#  'test']

# %%
import os
import re

# variables
path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
pattern = r'BFG_OPTUM_CLAIMS_'

# compile regex pattern 
regex = re.compile(pattern)

# listing all files in the directory
file_list = os.listdir(path)

# filtering files that match the pattern 
matching_files = []
for file in file_list:
    if regex.match(file): 
        matching_files.append(file)

print(matching_files)
# Out:
# ['BFG_OPTUM_CLAIMS_20230519.TXT', 'BFG_OPTUM_CLAIMS_20230222 (1).TXT', 'BFG_OPTUM_CLAIMS_20230222.TXT', 'BFG_OPTUM_CLAIMS_20230224.TXT', 'BFG_OPTUM_CLAIMS_20230303.TXT', 'BFG_OPTUM_CLAIMS_20230310.TXT', 'BFG_OPTUM_CLAIMS_20230324.TXT', 'BFG_OPTUM_CLAIMS_20230331.TXT', 'BFG_OPTUM_CLAIMS_20230407.TXT', 'BFG_OPTUM_CLAIMS_20230414.TXT', 'BFG_OPTUM_CLAIMS_20230317.TXT', 'BFG_OPTUM_CLAIMS_202304281.TXT', 'BFG_OPTUM_CLAIMS_20230526.TXT', 'BFG_OPTUM_CLAIMS_20230605.TXT', 'BFG_OPTUM_CLAIMS_20230609.TXT', 'BFG_OPTUM_CLAIMS_20230616.TXT', 'BFG_OPTUM_CLAIMS_20230428.TXT', 'BFG_OPTUM_CLAIMS_20230428_2.TXT', 'BFG_OPTUM_CLAIMS_20230512.TXT']

# %%
import os
import re
import pandas as pd


# variables
path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
pattern = r'BFG_OPTUM_CLAIMS_'

# compile regex pattern 
regex = re.compile(pattern)

# listing all files in the directory
file_list = os.listdir(path)

# filtering files that match the pattern 
matching_files = []
for file in file_list:
    if regex.match(file): 
        matching_files.append(file)

# converting to a dataframe
matching_files_df = pd.DataFrame(matching_files)
matching_files_df
# Out:
#                                     0
# 0       BFG_OPTUM_CLAIMS_20230519.TXT
# 1   BFG_OPTUM_CLAIMS_20230222 (1).TXT
# 2       BFG_OPTUM_CLAIMS_20230222.TXT
# 3       BFG_OPTUM_CLAIMS_20230224.TXT
# 4       BFG_OPTUM_CLAIMS_20230303.TXT
# 5       BFG_OPTUM_CLAIMS_20230310.TXT
# 6       BFG_OPTUM_CLAIMS_20230324.TXT
# 7       BFG_OPTUM_CLAIMS_20230331.TXT
# 8       BFG_OPTUM_CLAIMS_20230407.TXT
# 9       BFG_OPTUM_CLAIMS_20230414.TXT
# 10      BFG_OPTUM_CLAIMS_20230317.TXT
# 11     BFG_OPTUM_CLAIMS_202304281.TXT
# 12      BFG_OPTUM_CLAIMS_20230526.TXT
# 13      BFG_OPTUM_CLAIMS_20230605.TXT
# 14      BFG_OPTUM_CLAIMS_20230609.TXT
# 15      BFG_OPTUM_CLAIMS_20230616.TXT
# 16      BFG_OPTUM_CLAIMS_20230428.TXT
# 17    BFG_OPTUM_CLAIMS_20230428_2.TXT
# 18      BFG_OPTUM_CLAIMS_20230512.TXT

# %%
matching_files_df[0].str.extract('(OPTUM)')
# Out:
#         0
# 0   OPTUM
# 1   OPTUM
# 2   OPTUM
# 3   OPTUM
# 4   OPTUM
# 5   OPTUM
# 6   OPTUM
# 7   OPTUM
# 8   OPTUM
# 9   OPTUM
# 10  OPTUM
# 11  OPTUM
# 12  OPTUM
# 13  OPTUM
# 14  OPTUM
# 15  OPTUM
# 16  OPTUM
# 17  OPTUM
# 18  OPTUM

# %%
# Finding index value from a list using a regex
#   equivalent to the regexpr() function in R

date_list = []
for string in matching_files: 
    match = re.search(pattern, string)


    if match:
        date_start = match.end()
        date_list.append(date_start)

print(date_list)
# Out:
# [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]

# %%
# extracting substrings from file list

substr_list = [string[0:4] for string in matching_files]

print(substr_list)
# Out:
# ['BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_', 'BFG_']

# %%
import os
import re
import pandas as pd


# variables
path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
pattern = r'BFG_OPTUM_CLAIMS_'

# compile regex pattern 
regex = re.compile(pattern)

# listing all files in the directory
file_list = os.listdir(path)

# filtering files that match the pattern 
matching_files = []
for file in file_list:
    if regex.match(file): 
        matching_files.append(file)

# converting to a dataframe
matching_files_df = pd.DataFrame(matching_files)

print(matching_files_df)
# Out:
#                                     0
# 0       BFG_OPTUM_CLAIMS_20230519.TXT
# 1   BFG_OPTUM_CLAIMS_20230222 (1).TXT
# 2       BFG_OPTUM_CLAIMS_20230222.TXT
# 3       BFG_OPTUM_CLAIMS_20230224.TXT
# 4       BFG_OPTUM_CLAIMS_20230303.TXT
# 5       BFG_OPTUM_CLAIMS_20230310.TXT
# 6       BFG_OPTUM_CLAIMS_20230324.TXT
# 7       BFG_OPTUM_CLAIMS_20230331.TXT
# 8       BFG_OPTUM_CLAIMS_20230407.TXT
# 9       BFG_OPTUM_CLAIMS_20230414.TXT
# 10      BFG_OPTUM_CLAIMS_20230317.TXT
# 11     BFG_OPTUM_CLAIMS_202304281.TXT
# 12      BFG_OPTUM_CLAIMS_20230526.TXT
# 13      BFG_OPTUM_CLAIMS_20230605.TXT
# 14      BFG_OPTUM_CLAIMS_20230609.TXT
# 15      BFG_OPTUM_CLAIMS_20230616.TXT
# 16      BFG_OPTUM_CLAIMS_20230428.TXT
# 17    BFG_OPTUM_CLAIMS_20230428_2.TXT
# 18      BFG_OPTUM_CLAIMS_20230512.TXT

# %%
extracted_substrings = []
date_regex = r'BFG_OPTUM_CLAIMS_'

for file in matching_files:
    match = re.search(date_regex, file)
    if match:
        index_value = int(match.group())
        start_index = file.index(match.group())
        end_index = start_index + 8
        extracted_substrings.append(string[start_index:end_index])
    else: 
        extracted_substrings.append(None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 6
#       4 match = re.search(date_regex, file)
#       5 if match:
# ----> 6     index_value = int(match.group())
#       7     start_index = file.index(match.group())
#       8     end_index = start_index + 8
#
# ValueError: invalid literal for int() with base 10: 'BFG_OPTUM_CLAIMS_'

# %%
# sample list
string_list = ['file_20230701.txt', 'file_20230702.txt', 'file_20230703.txt', 'file_20230703.txt']

# integer indicies to extract substrings
start_index = 5
end_index = 13

# slicing the list
substrings = [string[start_index:end_index] for string in string_list]

print(substrings)
# Out:
# ['20230701', '20230702', '20230703', '20230703']

# %%
import os
import re
import pandas as pd

file_input_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_name_pattern = r'BFG_OPTUM_CLAIMS_'
date_start_regx = r'BFG_OPTUM_CLAIMS_'
date_length = 8

print(f"\nListing files from directory {file_input_path} ...")

# setting the working directory to file_input_path 
os.chdir(file_input_path)

# listing files from the dirctory that match file_name_pattern 
file_list = []
for f in os.listdir():
    if re.search(file_name_pattern, f): 
        file_list.append(f)

print(file_list)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# ['BFG_OPTUM_CLAIMS_20230519.TXT', 'BFG_OPTUM_CLAIMS_20230222 (1).TXT', 'BFG_OPTUM_CLAIMS_20230222.TXT', 'BFG_OPTUM_CLAIMS_20230224.TXT', 'BFG_OPTUM_CLAIMS_20230303.TXT', 'BFG_OPTUM_CLAIMS_20230310.TXT', 'BFG_OPTUM_CLAIMS_20230324.TXT', 'BFG_OPTUM_CLAIMS_20230331.TXT', 'BFG_OPTUM_CLAIMS_20230407.TXT', 'BFG_OPTUM_CLAIMS_20230414.TXT', 'BFG_OPTUM_CLAIMS_20230317.TXT', 'BFG_OPTUM_CLAIMS_202304281.TXT', 'BFG_OPTUM_CLAIMS_20230526.TXT', 'BFG_OPTUM_CLAIMS_20230605.TXT', 'BFG_OPTUM_CLAIMS_20230609.TXT', 'BFG_OPTUM_CLAIMS_20230616.TXT', 'BFG_OPTUM_CLAIMS_20230428.TXT', 'BFG_OPTUM_CLAIMS_20230428_2.TXT', 'BFG_OPTUM_CLAIMS_20230512.TXT']

# %%
import os
import re
import pandas as pd

file_input_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_name_pattern = r'BFG_OPTUM_CLAIMS_'
date_start_regx = r'BFG_OPTUM_CLAIMS_'
date_length = 8

print(f"\nListing files from directory {file_input_path} ...")

# setting the working directory to file_input_path 
os.chdir(file_input_path)

# listing files from the dirctory that match file_name_pattern 
file_list = []
for f in os.listdir():
    if re.search(file_name_pattern, f): 
        file_list.append(f)

index_list = []
for f in file_list:
    m = re.search(date_start_regx, f)
    if m: 
        index_list.append(m.end())

print(index_list)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]

# %%
import os
import re
import pandas as pd

file_input_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_name_pattern = r'BFG_OPTUM_CLAIMS_'
date_start_regx = r'BFG_OPTUM_CLAIMS_'
date_length = 8

print(f"\nListing files from directory {file_input_path} ...")

# setting the working directory to file_input_path 
os.chdir(file_input_path)

# listing files from the dirctory that match file_name_pattern 
file_list = []
for f in os.listdir():
    if re.search(file_name_pattern, f): 
        file_list.append(f)

# finding the index of the date in the file name
index_list = []
for f in file_list:
    m = re.search(date_start_regx, f)
    if m: 
        index_list.append(m.end())

# saving dates in a list
file_dates = []
for f, i, in zip(file_list, index_list):
    file_dates.append(f[i:i+date_length])

print(file_dates)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# ['20230519', '20230222', '20230222', '20230224', '20230303', '20230310', '20230324', '20230331', '20230407', '20230414', '20230317', '20230428', '20230526', '20230605', '20230609', '20230616', '20230428', '20230428', '20230512']

# %%
import os
import re
import pandas as pd

file_input_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_name_pattern = r'BFG_OPTUM_CLAIMS_'
date_start_regx = r'BFG_OPTUM_CLAIMS_'
date_length = 8

print(f"\nListing files from directory {file_input_path} ...")

# setting the working directory to file_input_path 
os.chdir(file_input_path)

# listing files from the dirctory that match file_name_pattern 
file_list = []
for f in os.listdir():
    if re.search(file_name_pattern, f): 
        file_list.append(f)

# finding the index of the date in the file name
index_list = []
for f in file_list:
    m = re.search(date_start_regx, f)
    if m: 
        index_list.append(m.end())

# saving dates in a list
file_dates = []
for f, i, in zip(file_list, index_list):
    file_dates.append(f[i:i+date_length])

# creating a data frame with the file_list and file_dates
file_list_df = pd.DataFrame({"file_list": file_list, "file_dates": file_dates})

file_list_df
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
#                             file_list file_dates
# 0       BFG_OPTUM_CLAIMS_20230519.TXT   20230519
# 1   BFG_OPTUM_CLAIMS_20230222 (1).TXT   20230222
# 2       BFG_OPTUM_CLAIMS_20230222.TXT   20230222
# 3       BFG_OPTUM_CLAIMS_20230224.TXT   20230224
# 4       BFG_OPTUM_CLAIMS_20230303.TXT   20230303
# 5       BFG_OPTUM_CLAIMS_20230310.TXT   20230310
# 6       BFG_OPTUM_CLAIMS_20230324.TXT   20230324
# 7       BFG_OPTUM_CLAIMS_20230331.TXT   20230331
# 8       BFG_OPTUM_CLAIMS_20230407.TXT   20230407
# 9       BFG_OPTUM_CLAIMS_20230414.TXT   20230414
# 10      BFG_OPTUM_CLAIMS_20230317.TXT   20230317
# 11     BFG_OPTUM_CLAIMS_202304281.TXT   20230428
# 12      BFG_OPTUM_CLAIMS_20230526.TXT   20230526
# 13      BFG_OPTUM_CLAIMS_20230605.TXT   20230605
# 14      BFG_OPTUM_CLAIMS_20230609.TXT   20230609
# 15      BFG_OPTUM_CLAIMS_20230616.TXT   20230616
# 16      BFG_OPTUM_CLAIMS_20230428.TXT   20230428
# 17    BFG_OPTUM_CLAIMS_20230428_2.TXT   20230428
# 18      BFG_OPTUM_CLAIMS_20230512.TXT   20230512

# %%
import os
import re
import pandas as pd

file_input_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_name_pattern = r'BFG_OPTUM_CLAIMS_'
date_start_regx = r'BFG_OPTUM_CLAIMS_'
date_length = 8

def list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length):
    print(f"\nListing files from directory {file_input_path} ...")

    # listing files from the dirctory that match file_name_pattern 
    file_list = []
    for f in os.listdir(file_input_path):
        if re.search(file_name_pattern, f): 
            file_list.append(f)

    # finding the index of the date in the file name
    index_list = []
    for f in file_list:
        m = re.search(date_start_regx, f)
        if m: 
            index_list.append(m.end())

    # saving dates in a list
    file_dates = []
    for f, i, in zip(file_list, index_list):
        file_dates.append(f[i:i+date_length])

    # creating a data frame with the file_list and file_dates
    file_list_df = pd.DataFrame({"file_list": file_list, "file_dates": file_dates})

    # returning file_list_df
    return(file_list_df)


list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
#                             file_list file_dates
# 0       BFG_OPTUM_CLAIMS_20230519.TXT   20230519
# 1   BFG_OPTUM_CLAIMS_20230222 (1).TXT   20230222
# 2       BFG_OPTUM_CLAIMS_20230222.TXT   20230222
# 3       BFG_OPTUM_CLAIMS_20230224.TXT   20230224
# 4       BFG_OPTUM_CLAIMS_20230303.TXT   20230303
# 5       BFG_OPTUM_CLAIMS_20230310.TXT   20230310
# 6       BFG_OPTUM_CLAIMS_20230324.TXT   20230324
# 7       BFG_OPTUM_CLAIMS_20230331.TXT   20230331
# 8       BFG_OPTUM_CLAIMS_20230407.TXT   20230407
# 9       BFG_OPTUM_CLAIMS_20230414.TXT   20230414
# 10      BFG_OPTUM_CLAIMS_20230317.TXT   20230317
# 11     BFG_OPTUM_CLAIMS_202304281.TXT   20230428
# 12      BFG_OPTUM_CLAIMS_20230526.TXT   20230526
# 13      BFG_OPTUM_CLAIMS_20230605.TXT   20230605
# 14      BFG_OPTUM_CLAIMS_20230609.TXT   20230609
# 15      BFG_OPTUM_CLAIMS_20230616.TXT   20230616
# 16      BFG_OPTUM_CLAIMS_20230428.TXT   20230428
# 17    BFG_OPTUM_CLAIMS_20230428_2.TXT   20230428
# 18      BFG_OPTUM_CLAIMS_20230512.TXT   20230512

# %%
file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
file_list_df['file_list']
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# 0         BFG_OPTUM_CLAIMS_20230519.TXT
# 1     BFG_OPTUM_CLAIMS_20230222 (1).TXT
# 2         BFG_OPTUM_CLAIMS_20230222.TXT
# 3         BFG_OPTUM_CLAIMS_20230224.TXT
# 4         BFG_OPTUM_CLAIMS_20230303.TXT
# 5         BFG_OPTUM_CLAIMS_20230310.TXT
# 6         BFG_OPTUM_CLAIMS_20230324.TXT
# 7         BFG_OPTUM_CLAIMS_20230331.TXT
# 8         BFG_OPTUM_CLAIMS_20230407.TXT
# 9         BFG_OPTUM_CLAIMS_20230414.TXT
# 10        BFG_OPTUM_CLAIMS_20230317.TXT
# 11       BFG_OPTUM_CLAIMS_202304281.TXT
# 12        BFG_OPTUM_CLAIMS_20230526.TXT
# 13        BFG_OPTUM_CLAIMS_20230605.TXT
# 14        BFG_OPTUM_CLAIMS_20230609.TXT
# 15        BFG_OPTUM_CLAIMS_20230616.TXT
# 16        BFG_OPTUM_CLAIMS_20230428.TXT
# 17      BFG_OPTUM_CLAIMS_20230428_2.TXT
# 18        BFG_OPTUM_CLAIMS_20230512.TXT
# Name: file_list, dtype: object

# %%
file_list_df.iloc[:,0]
# Out:
# 0         BFG_OPTUM_CLAIMS_20230519.TXT
# 1     BFG_OPTUM_CLAIMS_20230222 (1).TXT
# 2         BFG_OPTUM_CLAIMS_20230222.TXT
# 3         BFG_OPTUM_CLAIMS_20230224.TXT
# 4         BFG_OPTUM_CLAIMS_20230303.TXT
# 5         BFG_OPTUM_CLAIMS_20230310.TXT
# 6         BFG_OPTUM_CLAIMS_20230324.TXT
# 7         BFG_OPTUM_CLAIMS_20230331.TXT
# 8         BFG_OPTUM_CLAIMS_20230407.TXT
# 9         BFG_OPTUM_CLAIMS_20230414.TXT
# 10        BFG_OPTUM_CLAIMS_20230317.TXT
# 11       BFG_OPTUM_CLAIMS_202304281.TXT
# 12        BFG_OPTUM_CLAIMS_20230526.TXT
# 13        BFG_OPTUM_CLAIMS_20230605.TXT
# 14        BFG_OPTUM_CLAIMS_20230609.TXT
# 15        BFG_OPTUM_CLAIMS_20230616.TXT
# 16        BFG_OPTUM_CLAIMS_20230428.TXT
# 17      BFG_OPTUM_CLAIMS_20230428_2.TXT
# 18        BFG_OPTUM_CLAIMS_20230512.TXT
# Name: file_list, dtype: object

# %%
file_list_df['file_list'].loc[0]
# Out:
# 'BFG_OPTUM_CLAIMS_20230519.TXT'

# %%
file_list_df.at[0,'file_list']
# Out:
# 'BFG_OPTUM_CLAIMS_20230519.TXT'

# %%
file_list_df.iloc[0,0]
# Out:
# 'BFG_OPTUM_CLAIMS_20230519.TXT'

# %%
file_list_df.sort_values(by='file_dates', ascending=False)
# Out:
#                             file_list file_dates
# 15      BFG_OPTUM_CLAIMS_20230616.TXT   20230616
# 14      BFG_OPTUM_CLAIMS_20230609.TXT   20230609
# 13      BFG_OPTUM_CLAIMS_20230605.TXT   20230605
# 12      BFG_OPTUM_CLAIMS_20230526.TXT   20230526
# 0       BFG_OPTUM_CLAIMS_20230519.TXT   20230519
# 18      BFG_OPTUM_CLAIMS_20230512.TXT   20230512
# 11     BFG_OPTUM_CLAIMS_202304281.TXT   20230428
# 16      BFG_OPTUM_CLAIMS_20230428.TXT   20230428
# 17    BFG_OPTUM_CLAIMS_20230428_2.TXT   20230428
# 9       BFG_OPTUM_CLAIMS_20230414.TXT   20230414
# 8       BFG_OPTUM_CLAIMS_20230407.TXT   20230407
# 7       BFG_OPTUM_CLAIMS_20230331.TXT   20230331
# 6       BFG_OPTUM_CLAIMS_20230324.TXT   20230324
# 10      BFG_OPTUM_CLAIMS_20230317.TXT   20230317
# 5       BFG_OPTUM_CLAIMS_20230310.TXT   20230310
# 4       BFG_OPTUM_CLAIMS_20230303.TXT   20230303
# 3       BFG_OPTUM_CLAIMS_20230224.TXT   20230224
# 1   BFG_OPTUM_CLAIMS_20230222 (1).TXT   20230222
# 2       BFG_OPTUM_CLAIMS_20230222.TXT   20230222

# %%
file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)
first_file = file_list_df.iloc[0,0]
first_file
# Out:
# 'BFG_OPTUM_CLAIMS_20230616.TXT'

# %%
df = pd.read_csv(first_file, 
            delimiter = '|',
            skiprows = 0, 
            header = None, 
            dtype = str
            )

df.fillna('', inplace=True)
df
# Out:
#              0          1           2       3  4         5          6
# 0     11-172463  632587854      RIZVIC   HARIS     19921218     RIZVIC  \
# 1     11-172463  627108964       YOUNG    OLIN     19720731  YOUNG III
# 2     11-172463  627108964       YOUNG    OLIN     19720731  YOUNG III
# 3     11-172463  627108964       YOUNG    OLIN     19720731  YOUNG III
# 4     11-172463  627108964       YOUNG    OLIN     19720731  YOUNG III
# ...         ...        ...         ...     ... ..       ...        ...
# 2251  11-172463  307967652       LALEY   JASON     19711006      LALEY
# 2252  11-172463  307967652       LALEY   JASON     19711006      LALEY
# 2253  11-172463  307967652       LALEY   JASON     19711006      LALEY
# 2254  11-172463  315924402  DELAGRANGE  JOSEPH     19700926      KNAPP
# 2255  11-172463  407251299        BIRD   KEVIN     19841025       BIRD
#
#           7  8       9   ...        11                12      13
# 0      HARIS     BCBSAL  ...  20230531  5951588832017854   30.00  \
# 1       OLIN     BCBSAL  ...  20230605  3071591305018964   25.24
# 2       OLIN     BCBSAL  ...  20230605  3071591305028964    9.56
# 3       OLIN     BCBSAL  ...  20230605  3071591305038964    8.16
# 4       OLIN     BCBSAL  ...  20230605  3071591305048964    5.78
# ...      ... ..     ...  ...       ...               ...     ...
# 2251   TISHA     BCBSAL  ...  20230501  8851238013027652   30.00
# 2252   TISHA     BCBSAL  ...  20230501  8851238013037652   38.04
# 2253   TISHA     BCBSAL  ...  20230515  8851444791017652   25.00
# 2254  AUDRIA     BCBSAL  ...  20230504  3501323611014402  153.34
# 2255   KEVIN     BCBSAL  ...  20230315  5951229178011299  114.00
#
#                               14                15 16          17  18
# 0                LEFFERS KEVIN J        PO BOX 208     FORT WAYNE  IN  \
# 1     Laboratory Corp Of America       PO BOX 2270     BURLINGTON  NC
# 2     Laboratory Corp Of America       PO BOX 2270     BURLINGTON  NC
# 3     Laboratory Corp Of America       PO BOX 2270     BURLINGTON  NC
# 4     Laboratory Corp Of America       PO BOX 2270     BURLINGTON  NC
# ...                          ...               ... ..         ...  ..
# 2251   SASSMANNSHAUSEN JEFFREY W  5650 COVENTRY LN     FORT WAYNE  IN
# 2252   SASSMANNSHAUSEN JEFFREY W  5650 COVENTRY LN     FORT WAYNE  IN
# 2253         AINSWORTH MICHAEL E        PO BOX 151        DECATUR  IN
# 2254   COMMUNITY HOSPITALS AND W     433 W HIGH ST          BRYAN  OH
# 2255             AVIS JENNIFER L     PO BOX 950244     LOUISVILLE  KY
#
#              19                                                 20
# 0     468010208  US                                            ...
# 1     272162270  US                                            ...
# 2     272162270  US                                            ...
# 3     272162270  US                                            ...
# 4     272162270  US                                            ...
# ...         ...                                                ...
# 2251  468047140  US                                            ...
# 2252  468047140  US                                            ...
# 2253  467330151  US                                            ...
# 2254  435061690  US                                            ...
# 2255  402950244  US                                            ...
#
# [2256 rows x 21 columns]

# %%
df = pd.read_csv(first_file, 
            delimiter = '|',
            skiprows = 0, 
            header = None, 
            dtype = str
            )

df.fillna('', inplace=True)

df['FILE_NAME'] = first_file

df
# Out:
#               0          1           2       3 4          5          6
# 0     11-172463  632587854      RIZVIC   HARIS     19921218     RIZVIC  \
# 1     11-172463  627108964       YOUNG    OLIN     19720731  YOUNG III
# 2     11-172463  627108964       YOUNG    OLIN     19720731  YOUNG III
# 3     11-172463  627108964       YOUNG    OLIN     19720731  YOUNG III
# 4     11-172463  627108964       YOUNG    OLIN     19720731  YOUNG III
# ...         ...        ...         ...     ... ..       ...        ...
# 2251  11-172463  307967652       LALEY   JASON     19711006      LALEY
# 2252  11-172463  307967652       LALEY   JASON     19711006      LALEY
# 2253  11-172463  307967652       LALEY   JASON     19711006      LALEY
# 2254  11-172463  315924402  DELAGRANGE  JOSEPH     19700926      KNAPP
# 2255  11-172463  407251299        BIRD   KEVIN     19841025       BIRD
#
#            7 8        9  ...                12      13
# 0      HARIS     BCBSAL  ...  5951588832017854   30.00  \
# 1       OLIN     BCBSAL  ...  3071591305018964   25.24
# 2       OLIN     BCBSAL  ...  3071591305028964    9.56
# 3       OLIN     BCBSAL  ...  3071591305038964    8.16
# 4       OLIN     BCBSAL  ...  3071591305048964    5.78
# ...      ... ..     ...  ...               ...     ...
# 2251   TISHA     BCBSAL  ...  8851238013027652   30.00
# 2252   TISHA     BCBSAL  ...  8851238013037652   38.04
# 2253   TISHA     BCBSAL  ...  8851444791017652   25.00
# 2254  AUDRIA     BCBSAL  ...  3501323611014402  153.34
# 2255   KEVIN     BCBSAL  ...  5951229178011299  114.00
#
#                               14                15 16          17  18
# 0                LEFFERS KEVIN J        PO BOX 208     FORT WAYNE  IN  \
# 1     Laboratory Corp Of America       PO BOX 2270     BURLINGTON  NC
# 2     Laboratory Corp Of America       PO BOX 2270     BURLINGTON  NC
# 3     Laboratory Corp Of America       PO BOX 2270     BURLINGTON  NC
# 4     Laboratory Corp Of America       PO BOX 2270     BURLINGTON  NC
# ...                          ...               ... ..         ...  ..
# 2251   SASSMANNSHAUSEN JEFFREY W  5650 COVENTRY LN     FORT WAYNE  IN
# 2252   SASSMANNSHAUSEN JEFFREY W  5650 COVENTRY LN     FORT WAYNE  IN
# 2253         AINSWORTH MICHAEL E        PO BOX 151        DECATUR  IN
# 2254   COMMUNITY HOSPITALS AND W     433 W HIGH ST          BRYAN  OH
# 2255             AVIS JENNIFER L     PO BOX 950244     LOUISVILLE  KY
#
#              19                                                 20
# 0     468010208  US                                            ...  \
# 1     272162270  US                                            ...
# 2     272162270  US                                            ...
# 3     272162270  US                                            ...
# 4     272162270  US                                            ...
# ...         ...                                                ...
# 2251  468047140  US                                            ...
# 2252  468047140  US                                            ...
# 2253  467330151  US                                            ...
# 2254  435061690  US                                            ...
# 2255  402950244  US                                            ...
#
#                           FILE_NAME
# 0     BFG_OPTUM_CLAIMS_20230616.TXT
# 1     BFG_OPTUM_CLAIMS_20230616.TXT
# 2     BFG_OPTUM_CLAIMS_20230616.TXT
# 3     BFG_OPTUM_CLAIMS_20230616.TXT
# 4     BFG_OPTUM_CLAIMS_20230616.TXT
# ...                             ...
# 2251  BFG_OPTUM_CLAIMS_20230616.TXT
# 2252  BFG_OPTUM_CLAIMS_20230616.TXT
# 2253  BFG_OPTUM_CLAIMS_20230616.TXT
# 2254  BFG_OPTUM_CLAIMS_20230616.TXT
# 2255  BFG_OPTUM_CLAIMS_20230616.TXT
#
# [2256 rows x 22 columns]

# %%
file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)

for f in file_list_df['file_list']:
    print(f)

# %%
file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)

# creating empty dataframe 
batch = pd.DataFrame()

# iterating through list of files
for f in file_list_df['file_list']:
    
    print(f"reading file... {f}")

    # reading data frame
    df = pd.read_csv(f, 
            delimiter = '|',
            skiprows = 0, 
            header = None, 
            dtype = str
            )
    
    # removing NAs
    df.fillna('', inplace=True)

    # adding file_name column
    df['FILE_NAME'] = f

    # concating rows to the batch dataframe
    batch = pd.concat([batch, df])

print(f"\nfiles batched!")
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# reading file... BFG_OPTUM_CLAIMS_20230616.TXT
# reading file... BFG_OPTUM_CLAIMS_20230609.TXT
# reading file... BFG_OPTUM_CLAIMS_20230605.TXT
# reading file... BFG_OPTUM_CLAIMS_20230526.TXT
# reading file... BFG_OPTUM_CLAIMS_20230519.TXT
# reading file... BFG_OPTUM_CLAIMS_20230512.TXT
# reading file... BFG_OPTUM_CLAIMS_202304281.TXT
# reading file... BFG_OPTUM_CLAIMS_20230428.TXT
# reading file... BFG_OPTUM_CLAIMS_20230428_2.TXT
# reading file... BFG_OPTUM_CLAIMS_20230414.TXT
# reading file... BFG_OPTUM_CLAIMS_20230407.TXT
# reading file... BFG_OPTUM_CLAIMS_20230331.TXT
# reading file... BFG_OPTUM_CLAIMS_20230324.TXT
# reading file... BFG_OPTUM_CLAIMS_20230317.TXT
# reading file... BFG_OPTUM_CLAIMS_20230310.TXT
# reading file... BFG_OPTUM_CLAIMS_20230303.TXT
# reading file... BFG_OPTUM_CLAIMS_20230224.TXT
# reading file... BFG_OPTUM_CLAIMS_20230222 (1).TXT
# reading file... BFG_OPTUM_CLAIMS_20230222.TXT
#
# files batched!

# %%
# getting date range from the list of files within the folder 
file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)
files_start_dt = file_list_df.iloc[0,1]
files_end_dt = file_list_df.iloc[-1,1]
print(files_start_dt)
print(files_end_dt)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# 20230616
# 20230222

# %%
def concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regx, date_length):
    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        print(f"reading file... {f}")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = '|',
                skiprows = 0, 
                header = None, 
                dtype = str
                )

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = f

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    # getting date range from the list of files within the folder 
    files_start_dt = file_list_df.iloc[0,1]
    files_end_dt = file_list_df.iloc[-1,1]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)

# %%
import os
import re
import pandas as pd

file_input_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_name_pattern = r'BFG_OPTUM_CLAIMS_'
date_start_regx = r'BFG_OPTUM_CLAIMS_'
date_length = 8


def concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regx, date_length):

    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        print(f"reading file... {f}")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = '|',
                skiprows = 0, 
                header = None, 
                dtype = str
                )

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = f

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    # getting date range from the list of files within the folder 
    files_start_dt = file_list_df.iloc[0,1]
    files_end_dt = file_list_df.iloc[-1,1]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)

batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# reading file... BFG_OPTUM_CLAIMS_20230616.TXT
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 50
#      47     # returning variables
#      48     return(batch, file_name_pattern, files_start_dt, files_end_dt)
# ---> 50 batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regex, date_length)
#
# Cell In[48], line 25, in concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regex, date_length)
#      22 print(f"reading file... {f}")
#      24 # reading data frame
# ---> 25 df = pd.read_csv(f,
#      26         delimiter = '|',
#      27         skiprows = 0,
#      28         header = None,
#      29         dtype = str
#      30         )
#      32 # removing NAs
#      33 df.fillna('', inplace=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'BFG_OPTUM_CLAIMS_20230616.TXT'

# %%
import os
import re
import pandas as pd

file_input_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_name_pattern = r'BFG_OPTUM_CLAIMS_'
date_start_regx = r'BFG_OPTUM_CLAIMS_'
date_length = 8


def concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regx, date_length):

    # Getting dates from file names, storing them in a dataframe
    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        print(f"reading file... {f}")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = '|',
                skiprows = 0, 
                header = None, 
                dtype = str
                )

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = f

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    # getting date range from the list of files within the folder 
    files_start_dt = file_list_df.iloc[0,1]
    files_end_dt = file_list_df.iloc[-1,1]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)

# %%
import json


os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_BCBSAL']['file_input_path']
file_name_pattern = config['Michelin_Union_BCBSAL']['file_name_pattern']
date_start_regx   = config['Michelin_Union_BCBSAL']['date_start_regx']
date_length       = config['Michelin_Union_BCBSAL']['date_length']


print(file_input_path)
print(file_name_pattern)
print(date_start_regx)
print(date_length)
# Out:
# N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL
# BFG_OPTUM_CLAIMS_
# BFG_OPTUM_CLAIMS_
# 8

# %%
import json
import os
import re
import pandas as pd

# changing directory to Michelin Union folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open a read json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file
file_input_path   = config['Michelin_Union_MedImpact']['file_input_path']
file_name_pattern = config['Michelin_Union_MedImpact']['file_name_pattern']
date_start_regx   = config['Michelin_Union_MedImpact']['date_start_regx']
date_length       = config['Michelin_Union_MedImpact']['date_length']

# running MedImpact concat
def concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regx, date_length):

    # Getting dates from file names, storing them in a dataframe
    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        print(f"reading file... {f}")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = '|',
                skiprows = 0, 
                header = None, 
                dtype = str
                )

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = f

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    # getting date range from the list of files within the folder 
    files_start_dt = file_list_df.iloc[0,1]
    files_end_dt = file_list_df.iloc[-1,1]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)


batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MedImpact ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 61
#      57     # returning variables
#      58     return(batch, file_name_pattern, files_start_dt, files_end_dt)
# ---> 61 batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regex, date_length)
#
# Cell In[47], line 23, in concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regex, date_length)
#      20 def concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regex, date_length):
#      21
#      22     # Getting dates from file names, storing them in a dataframe
# ---> 23     file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regex, date_length)
#      24     file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)
#      26     # creating empty dataframe
#
# Cell In[20], line 35, in list_files_date_regx(file_input_path, file_name_pattern, date_start_regex, date_length)
#      32     file_dates.append(f[i:i+date_length])
#      34 # creating a data frame with the file_list and file_dates
# ---> 35 file_list_df = pd.DataFrame({"file_list": file_list, "file_dates": file_dates})
#      37 # returning file_list_df
#      38 return(file_list_df)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %%
#  Returning absolute path instead of file name 

import os
import re
import pandas as pd

file_input_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL'
file_name_pattern = r'BFG_OPTUM_CLAIMS_'
date_start_regx = r'BFG_OPTUM_CLAIMS_'
date_length = 8


def list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length):
    print(f"\n\nListing files from directory {file_input_path} ...")

    # setting the working directory to file_input_path 
    # os.chdir(file_input_path)


    # listing files from the directory that match file_name_pattern 
    file_list = []
    for f in os.listdir(file_input_path):
        if re.search(file_name_pattern, f):
            
            # getting absolute path and converting to raw string
            fpath = file_input_path + '/' + f

            # attaching path to file_list
            file_list.append(fpath)

    # finding the index of the date in the file name
    index_list = []
    for f in file_list:
        m = re.search(date_start_regx, f)
        if m: 
            index_list.append(m.end())

    # saving dates in a list
    file_dates = []
    for f, i, in zip(file_list, index_list):
        file_dates.append(f[i:i+date_length])

    # creating a data frame with the file_list and file_dates
    file_list_df = pd.DataFrame({"file_list": file_list, "file_dates": file_dates})

    # returning file_list_df
    return(file_list_df)

list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
#                                             file_list file_dates
# 0   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230519
# 1   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230222
# 2   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230222
# 3   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230224
# 4   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230303
# 5   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230310
# 6   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230324
# 7   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230331
# 8   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230407
# 9   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230414
# 10  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230317
# 11  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230428
# 12  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230526
# 13  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230605
# 14  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230609
# 15  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230616
# 16  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230428
# 17  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230428
# 18  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230512

# %%
import os
import re
import pandas as pd
import json

os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_BCBSAL']['file_input_path']
file_name_pattern = config['Michelin_Union_BCBSAL']['file_name_pattern']
date_start_regx   = config['Michelin_Union_BCBSAL']['date_start_regx']
date_length       = config['Michelin_Union_BCBSAL']['date_length']

def list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length):
    print(f"\n\nListing files from directory {file_input_path} ...")

    # setting the working directory to file_input_path 
    # os.chdir(file_input_path)


    # listing files from the directory that match file_name_pattern 
    file_list = []
    for f in os.listdir(file_input_path):
        if re.search(file_name_pattern, f):
            
            # getting absolute path and converting to raw string
            fpath = file_input_path + '/' + f

            # attaching path to file_list
            file_list.append(fpath)

    # finding the index of the date in the file name
    index_list = []
    for f in file_list:
        m = re.search(date_start_regx, f)
        if m: 
            index_list.append(m.end())

    # saving dates in a list
    file_dates = []
    for f, i, in zip(file_list, index_list):
        file_dates.append(f[i:i+date_length])

    # creating a data frame with the file_list and file_dates
    file_list_df = pd.DataFrame({"file_list": file_list, "file_dates": file_dates})

    # returning file_list_df
    return(file_list_df)

def concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regx, date_length):

    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        # retrieving the base file name for logging
        fName = os.path.basename(f)

        print(f"reading file... {fName}")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = '|',
                skiprows = 0, 
                header = None, 
                dtype = str
                )

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = fName

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    # getting date range from the list of files within the folder 
    files_start_dt = file_list_df.iloc[0,1]
    files_end_dt = file_list_df.iloc[-1,1]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)

batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# reading file... BFG_OPTUM_CLAIMS_20230616.TXT
# reading file... BFG_OPTUM_CLAIMS_20230609.TXT
# reading file... BFG_OPTUM_CLAIMS_20230605.TXT
# reading file... BFG_OPTUM_CLAIMS_20230526.TXT
# reading file... BFG_OPTUM_CLAIMS_20230519.TXT
# reading file... BFG_OPTUM_CLAIMS_20230512.TXT
# reading file... BFG_OPTUM_CLAIMS_202304281.TXT
# reading file... BFG_OPTUM_CLAIMS_20230428.TXT
# reading file... BFG_OPTUM_CLAIMS_20230428_2.TXT
# reading file... BFG_OPTUM_CLAIMS_20230414.TXT
# reading file... BFG_OPTUM_CLAIMS_20230407.TXT
# reading file... BFG_OPTUM_CLAIMS_20230331.TXT
# reading file... BFG_OPTUM_CLAIMS_20230324.TXT
# reading file... BFG_OPTUM_CLAIMS_20230317.TXT
# reading file... BFG_OPTUM_CLAIMS_20230310.TXT
# reading file... BFG_OPTUM_CLAIMS_20230303.TXT
# reading file... BFG_OPTUM_CLAIMS_20230224.TXT
# reading file... BFG_OPTUM_CLAIMS_20230222 (1).TXT
# reading file... BFG_OPTUM_CLAIMS_20230222.TXT
#
# files batched!

# %%
import os
import re
import pandas as pd
import json

os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_MedImpact']['file_input_path']
file_name_pattern = config['Michelin_Union_MedImpact']['file_name_pattern']
date_start_regx   = config['Michelin_Union_MedImpact']['date_start_regx']
date_length       = config['Michelin_Union_MedImpact']['date_length']

def list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length):
    print(f"\n\nListing files from directory {file_input_path} ...")

    # setting the working directory to file_input_path 
    # os.chdir(file_input_path)


    # listing files from the directory that match file_name_pattern 
    file_list = []
    for f in os.listdir(file_input_path):
        if re.search(file_name_pattern, f):
            
            # getting absolute path and converting to raw string
            fpath = file_input_path + '/' + f

            # attaching path to file_list
            file_list.append(fpath)

    # finding the index of the date in the file name
    index_list = []
    for f in file_list:
        m = re.search(date_start_regx, f)
        if m: 
            index_list.append(m.end())

    # saving dates in a list
    file_dates = []
    for f, i, in zip(file_list, index_list):
        file_dates.append(f[i:i+date_length])

    # creating a data frame with the file_list and file_dates
    file_list_df = pd.DataFrame({"file_list": file_list, "file_dates": file_dates})

    # returning file_list_df
    return(file_list_df)

def concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regx, date_length):

    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        # retrieving the base file name for logging
        fName = os.path.basename(f)

        print(f"reading file... {fName}")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = '|',
                skiprows = 0, 
                header = None, 
                dtype = str
                )

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = fName

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    # getting date range from the list of files within the folder 
    files_start_dt = file_list_df.iloc[0,1]
    files_end_dt = file_list_df.iloc[-1,1]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)

batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MedImpact ...
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230612_20230618_202306190102.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230605_20230611_202306120103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230529_20230604_202306050103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230522_20230528_202305290103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230515_20230521_202305220103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230508_20230514_202305150103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230501_20230507_202305080103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230424_20230430_202305010102.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230417_20230423_202304240105.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230410_20230416_202304170103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230403_20230409_202304100104.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230327_20230402_202304030103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230320_20230326_202303270103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230313_20230319_202303200103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230306_20230312_202303130103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230227_20230305_202303060103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230220_20230226_202302270103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230213_20230219_202302200103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230206_20230212_202302130102.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230130_20230205_202302060102.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230123_20230129_202301300103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230116_20230122_202301230107.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230109_20230115_202301160103.dat
# reading file... type112_mna05_mna09_mna16_t112_nov_optum_20230102_20230108_202301090104.dat
#
# files batched!

# %%
import os
import re
import pandas as pd
import json

os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_MedImpact']['file_input_path']
file_name_pattern = config['Michelin_Union_MedImpact']['file_name_pattern']
date_start_regx   = config['Michelin_Union_MedImpact']['date_start_regx']
date_length       = config['Michelin_Union_MedImpact']['date_length']


def list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length):
    print(f"\n\nListing files from directory {file_input_path} ...")

    # setting the working directory to file_input_path 
    # os.chdir(file_input_path)


    # listing files from the directory that match file_name_pattern 
    file_list = []
    for f in os.listdir(file_input_path):
        if re.search(file_name_pattern, f):
            
            # getting absolute path and converting to raw string
            fpath = file_input_path + '/' + f

            # attaching path to file_list
            file_list.append(fpath)

    # finding the index of the date in the file name
    index_list = []
    for f in file_list:
        m = re.search(date_start_regx, f)
        if m: 
            index_list.append(m.end())

    # saving dates in a list
    file_dates = []
    for f, i, in zip(file_list, index_list):
        file_dates.append(f[i:i+date_length])

    # creating a data frame with the file_list and file_dates
    file_list_df = pd.DataFrame({"file_list": file_list, "file_dates": file_dates})

    # returning file_list_df
    return(file_list_df)

list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MedImpact ...
#                                             file_list file_dates
# 0   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230327
# 1   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230403
# 2   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230410
# 3   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230417
# 4   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230424
# 5   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230102
# 6   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230109
# 7   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230116
# 8   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230123
# 9   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230130
# 10  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230206
# 11  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230213
# 12  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230220
# 13  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230227
# 14  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230306
# 15  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230313
# 16  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230320
# 17  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230522
# 18  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230529
# 19  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230605
# 20  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230612
# 21  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230501
# 22  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230508
# 23  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O...   20230515

# %%
import os
import re
import pandas as pd
import json
from functions import list_files_date_regx

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_Metlife']['file_input_path']
file_name_pattern = config['Michelin_Union_Metlife']['file_name_pattern']
date_start_regx   = config['Michelin_Union_Metlife']['date_start_regx']
date_length       = config['Michelin_Union_Metlife']['date_length']

# converting dates to standard format - include this in the list_files_date_regx() function? 
# how would I handle the situation where file names do not include dates? 

files = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)

files['file_dates'] = pd.to_datetime(files['file_dates'], format = '%m%d%Y')

files
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MetLife ...
#                                             file_list file_dates
# 0   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-06-21
# 1   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-06-14
# 2   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-06-07
# 3   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-05-31
# 4   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-05-24
# 5   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-05-17
# 6   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-05-10
# 7   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-05-03
# 8   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-04-26
# 9   N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-04-19
# 10  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-04-12
# 11  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-04-05
# 12  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-03-29
# 13  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-03-22
# 14  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-03-15
# 15  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-03-08
# 16  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-03-01
# 17  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-02-22
# 18  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-02-15
# 19  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-02-08
# 20  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-02-01
# 21  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-01-25
# 22  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-01-18
# 23  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-01-11
# 24  N:/OPTClaimsConversion/Incoming/OHFSIncoming/O... 2023-01-04

# %%
import os
import re
import pandas as pd
import json
from functions import list_files_date_regx

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_Metlife']['file_input_path']
file_name_pattern = config['Michelin_Union_Metlife']['file_name_pattern']
date_start_regx   = config['Michelin_Union_Metlife']['date_start_regx']
date_length       = config['Michelin_Union_Metlife']['date_length']

def concat_Michelin_Union_Metlife(file_input_path, file_name_pattern, date_start_regx, date_length):

    # listing files
    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    file_list_df['file_dates'] = pd.to_datetime(file_list_df['file_dates'], format = '%m%d%Y')     # converting dates 
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)                      # sorting 


    # creating empty dataframe 
    batch = pd.DataFrame()


    # iterating through list of files
    for f in file_list_df['file_list']:

        # retrieving the base file name for logging
        fName = os.path.basename(f)

        print(f"reading file... {fName}")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = '|',
                skiprows = 1, 
                header = 0, 
                dtype = str,
                encoding= 'unicode_escape'
                )

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = fName

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")


    # getting date range from the list of files within the folder 
    files_start_dt = file_list_df.iloc[0,1]
    files_end_dt = file_list_df.iloc[-1,1]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)

batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_Metlife(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MetLife ...
# reading file... Optum_metlife_06212023.txt
# reading file... Optum_metlife_06142023.txt
# reading file... Optum_metlife_06072023.txt
# reading file... Optum_metlife_05312023.txt
# reading file... Optum_metlife_05242023.txt
# reading file... Optum_metlife_05172023.txt
# reading file... Optum_metlife_05102023.txt
# reading file... Optum_metlife_05032023.txt
# reading file... Optum_metlife_04262023.txt
# reading file... Optum_metlife_04192023.txt
# reading file... Optum_metlife_04122023.txt
# reading file... Optum_metlife_04052023.txt
# reading file... Optum_metlife_03292023.txt
# reading file... Optum_metlife_03222023.txt
# reading file... Optum_metlife_03152023.txt
# reading file... Optum_metlife_03082023.txt
# reading file... Optum_metlife_03012023.txt
# reading file... Optum_metlife_02222023.txt
# reading file... Optum_metlife_02152023.txt
# reading file... Optum_metlife_02082023.txt
# reading file... Optum_metlife_02012023.txt
# reading file... Optum_metlife_01252023.txt
# reading file... Optum_metlife_01182023.txt
# reading file... Optum_metlife_01112023.txt
# reading file... Optum_metlife_01042023.txt
#
# files batched!

# %%
# reading data frame

f = "N:\\OPTClaimsConversion\\Incoming\\OHFSIncoming\\OHFSArchive\\Michelin Union\\MetLife\\Optum_metlife_04262023.txt"
df = pd.read_csv(f, 
        delimiter = '|',
        skiprows = 1, 
        header = 0, 
        dtype = str, 
        encoding= 'unicode_escape' # fixes the UTF-8 error
        )

df
# Out:
#                                         EMPLOYER_TAX_ID PARTICIPANT_SSN
# 0                                               0119192       465911385  \
# 1                                               2333000       254610626
# 2                                               2333000       389946681
# 3                                               2333000       391807875
# 4                                               2333000       528453244
# ...                                                 ...             ...
# 2728                                            2665775       626790848
# 2729                                            2665775       637108272
# 2730                                            2665775       761527500
# 2731                                            2665775       896997265
# 2732  0002732T                                      ...             NaN
#
#      PARTICIPANT_LAST_NAME PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                     RELA                JESSICA                        NaN  \
# 1                     DEAN                 MARVIN                        NaN
# 2                    LEMAY                  WAYDA                        NaN
# 3                     GAAL                   MARY                        NaN
# 4                 PETERSON                 ELISHA                        NaN
# ...                    ...                    ...                        ...
# 2728                 SINGH                 SATISH                        NaN
# 2729                  GUIN                WILLIAM                        NaN
# 2730                  NAND                ATILESH                        NaN
# 2731             SADAGOPAN             RENGARAJAN                        NaN
# 2732                   NaN                    NaN                        NaN
#
#      PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                       020309              RELA              JONAS  \
# 1                       111270            GAINES             RACHEL
# 2                       052804              THAO            BRIANNA
# 3                       011809              GAAL            BRYNNLY
# 4                       090409          PETERSON              ALLEE
# ...                        ...               ...                ...
# 2728                    052777             SINGH             SATISH
# 2729                    080386              GUIN                NaN
# 2730                    050786              NAND            ATILESH
# 2731                    021382        RAJAMANNAR            MANJULA
# 2732                       NaN               NaN                NaN
#
#      PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...       CLAIM_NUMBER
# 0                       NaN              D  ...  22106063866201879  \
# 1                       NaN              D  ...  22109229625801971
# 2                       NaN              D  ...  22106161022001977
# 3                       NaN              D  ...  22111153335001982
# 4                       NaN              D  ...  22111153271301982
# ...                     ...            ...  ...                ...
# 2728                    NaN              D  ...  22304243489200299
# 2729                    NaN              D  ...  22304249674100299
# 2730                    NaN              D  ...  22304213126600299
# 2731                    NaN              D  ...  22304243023500299
# 2732                    NaN            NaN  ...                NaN
#
#      CLAIM_AMOUNT           PROVIDER_NAME                 PROVIDER_ADDRESS1
# 0       00001995{            CRAIG TAYLOR  LONE STAR PEDIATRIC DENTAL AND B  \
# 1       00002100{            QUANG NGUYEN                QUANG L NGUYEN DMD
# 2       00001560{      JOHN-DAVID BEUHLER         DEERWOOD ORTHODONTICS LLC
# 3       00002100{     R ANDREW KOKODYNSKI        R ANDREW KOKODYNSKI DDS SC
# 4       00001630{           KAMERON KUHNI              KOS SPANISH FORK LLC
# ...           ...                     ...                               ...
# 2728    00000320{               VU NGUYEN  GILBERT MODERN DENTISTRY AND ORT
# 2729    00000310{          JEREMY WEHRMAN                SMILE SOLUTIONS PC
# 2730    00000270{  CHAITANYA BANDARUPALLI         CHAITANYA DENTAL CARE INC
# 2731    00000872{            NISHITH SHAH      ARIZONIA ORAL FACIAL & IMPLA
# 2732          NaN                     NaN                               NaN
#
#                  PROVIDER_ADDRESS2  PROVIDER_CITY PROVIDER_STATE PROVIDER_ZIP
# 0       8716 RESEARCH BLVD STE 125         AUSTIN             TX   78758-6420  \
# 1                   1605 BUFORD DR  LAWRENCEVILLE             GA   30043-7717
# 2     5100 W FOREST HOME AVE # 203      MILWAUKEE             WI   54911-8707
# 3               201 S PERKINS BLVD     BURLINGTON             WI   53105-1909
# 4                      948 N 200 E   SPANISH FORK             UT   84660-1247
# ...                            ...            ...            ...          ...
# 2728            17000 RED HILL AVE         IRVINE             CA   85298-4335
# 2729          1910 42ND ST S STE A          FARGO             ND   58103-4416
# 2730            43693 MISSION BLVD        FREMONT             CA   94539-5832
# 2731           2450 W RAY RD STE 1       CHANDLER             AZ   85224-3595
# 2732                           NaN            NaN            NaN          NaN
#
#      PROVIDER_COUNTRY
# 0                  US  \
# 1                  US
# 2                  US
# 3                  US
# 4                  US
# ...               ...
# 2728               US
# 2729               US
# 2730               US
# 2731               US
# 2732              NaN
#
#      CLAIM_TYPE
# 0                                                   ...
# 1                                                   ...
# 2                                                   ...
# 3                                                   ...
# 4                                                   ...
# ...                                                 ...
# 2728                                                ...
# 2729                                                ...
# 2730                                                ...
# 2731                                                ...
# 2732                                                NaN
#
# [2733 rows x 22 columns]

# %%
import os
# import re
import pandas as pd
import json
from functions import list_files_date_regx

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_VSP']['file_input_path']
file_name_pattern = config['Michelin_Union_VSP']['file_name_pattern']
date_start_regx   = config['Michelin_Union_VSP']['date_start_regx']
date_length       = config['Michelin_Union_VSP']['date_length']

def concat_Michelin_Union_VSP(file_input_path, file_name_pattern, date_start_regx, date_length):

    # listing files
    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    # file_list_df['file_dates'] = pd.to_datetime(file_list_df['file_dates'], format = '%m%d%Y')     # converting dates 
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)                      # sorting 


    # creating empty dataframe 
    batch = pd.DataFrame()


    # iterating through list of files
    for f in file_list_df['file_list']:

        # retrieving the base file name for logging
        fName = os.path.basename(f)

        print(f"reading file... {fName}")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = ',',
                skiprows = 0, 
                header = None, 
                dtype = str,
                # encoding= 'unicode_escape'
                )

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = fName

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    # getting date range from the list of files within the folder 
    files_start_dt = file_list_df.iloc[0,1]
    files_end_dt = file_list_df.iloc[-1,1]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)

batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_VSP(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/VSP ...
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230527.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230512.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230428.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230411.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230403.txt
# reading file... VSP_FSA_MICHELIN_05102922_20230328.txt
# reading file... VSP_FSA_MICHELIN_05102922_20230312.txt
# reading file... VSP_FSA_MICHELIN_05102922_20230228.txt
# reading file... VSP_FSA_MICHELIN_05102922_20230227.txt
#
# files batched!

# %%
### Mappings

# %%
batch
# Out:
#              0          1            2          3  4         5           6
# 0    111724631  291446635     MARBAUGH      BRETT     19590928    MARBAUGH  \
# 1    111724631  276806154       JEWELL  RICHARD D  D  19710702      JEWELL
# 2    111724631  301601279    VANVLERAH    STEVE M  M  19651014  VAN VLERAH
# 3    111724631  422027161          NIX  MICHAEL H  H  19611109         NIX
# 4    111724631  472924762     FLANAGAN     JOHN L  L  19621021    FLANAGAN
# ..         ...        ...          ...        ... ..       ...         ...
# 283  111724631  423316322         AGEE      JAMES  P  19840121      BARNES
# 284  111724631  422478055        CURRY   QUEMONTE  D  19980111       CURRY
# 285  111724631  422927958       BRYANT   VERNANDO  O  19731025      BRYANT
# 286  111724631  423212411      REED JR     MELVIN  A  19710302     REED JR
# 287  111724631  419270798  PRENTICE JR     VICTOR  N  19740713    PRENTICE
#
#                7  8    9  ...      13                                14
# 0          BRETT     VSP  ...   99.44            WALMART STORES EAST LP  \
# 1       AMANDA J     VSP  ...  722.60               Mercer In Sight LLC
# 2         TAMARA     VSP  ...  374.20             A Hoffman Enterprises
# 3      MICHAEL H     VSP  ...  280.20         Martin Family Eyecare LLC
# 4    FLORRENDA K     VSP  ...     .00  Aboite Family Eyecare Center Inc
# ..           ... ..  ...  ...     ...                               ...
# 283        PIPER     VSP  ...   34.00                      Ce Bonds LLC
# 284     QUEMONTE  D  VSP  ...   83.00           Wal Mart Stores East Lp
# 285       CORRIE     VSP  ...     .00         Martin Family Eyecare LLC
# 286       MELVIN  A  VSP  ...   46.00           Wal Mart Stores East Lp
# 287       BOBBIE  L  VSP  ...     .00         Martin Family Eyecare LLC
#
#                              15 16          17  18     19  20 21
# 0              1950 HAVEMANN RD         CELINA  OH  45822  US     \
# 1                 321 W Main St       Van Wert  OH  45891  US
# 2                 203 N Main St     Hicksville  OH  43526  US
# 3                  925 Mally St     Tuscaloosa  AL  35405  US
# 4         7625 W Jefferson Blvd     Fort Wayne  IN  46804  US
# ..                          ... ..         ...  ..    ...  .. ..
# 283  1701 McFarland Blvd E Suit     Tuscaloosa  AL  35404  US
# 284         1501 Skyland Blvd E     Tuscaloosa  AL  35405  US
# 285                925 Mally St     Tuscaloosa  AL  35405  US
# 286         5710 McFarland Blvd      Northport  AL  35476  US
# 287                925 Mally St     Tuscaloosa  AL  35405  US
#
#                                         FILE_NAME
# 0    VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 1    VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 2    VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 3    VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 4    VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# ..                                            ...
# 283        VSP_FSA_MICHELIN_05102922_20230227.txt
# 284        VSP_FSA_MICHELIN_05102922_20230227.txt
# 285        VSP_FSA_MICHELIN_05102922_20230227.txt
# 286        VSP_FSA_MICHELIN_05102922_20230227.txt
# 287        VSP_FSA_MICHELIN_05102922_20230227.txt
#
# [1205 rows x 23 columns]

# %%
for col in output_df.columns:
    print(f"{col}: {output_df[col].dtype}")
# Out:
# FILE_TYPE: object
# EXPENSE_CATEGORY: object
# EMPLOYER_TAX_ID: object
# PARTICIPANT_SSN: object
# PARTICIPANT_LAST_NAME: object
# PARTICIPANT_FIRST_NAME: object
# PARTICIPANT_MIDDLE_INITIAL: object
# PARTICIPANT_DATE_OF_BIRTH: object
# PATIENT_LAST_NAME: object
# PATIENT_FIRST_NAME: object
# PATIENT_MIDDLE_INITIAL: object
# CARRIER_SYSTEM: object
# SERVICE_START_DATE: object
# SERVICE_THRU_DATE: object
# CLAIM_NUMBER: object
# CLAIM_AMOUNT: object
# PROVIDER_NAME: object
# PROVIDER_ADDRESS1: object
# PROVIDER_ADDRESS2: object
# PROVIDER_CITY: object
# PROVIDER_STATE: object
# PROVIDER_ZIP: object
# PROVIDER_COUNTRY: object
# CLAIM_TYPE: object

# %%
for col in batch.columns:
    print(f"{col}: {batch[col].dtype}")
# Out:
# 0: object
# 1: object
# 2: object
# 3: object
# 4: object
# 5: object
# 6: object
# 7: object
# 8: object
# 9: object
# 10: object
# 11: object
# 12: object
# 13: object
# 14: object
# 15: object
# 16: object
# 17: object
# 18: object
# 19: object
# 20: object
# 21: object
# FILE_NAME: object

# %%
import pandas as pd
import json 

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

output_header      = config['output']['output_header']
file_output_path   = config['output']['file_output_path']
file_name_pattern  = config['Michelin_Union_VSP']['file_name_pattern']

print (f'\nmapping {file_name_pattern} to a standard format... \n')

# creating a data frame with specified output_header
output_df = pd.DataFrame(columns=output_header, dtype=str)
# output_df = output_df.astype(str)

# Filling in DataFrame columns from the batch dataframe 
output_df['EMPLOYER_TAX_ID']            = batch[0]
output_df['PARTICIPANT_SSN']            = batch[1]
output_df['PARTICIPANT_LAST_NAME']      = batch[2]
output_df['PARTICIPANT_FIRST_NAME']     = batch[3]
output_df['PARTICIPANT_MIDDLE_INITIAL'] = batch[4]
output_df['PARTICIPANT_DATE_OF_BIRTH']  = batch[5]
output_df['PATIENT_LAST_NAME']          = batch[6]
output_df['PATIENT_FIRST_NAME']         = batch[7]
output_df['PATIENT_MIDDLE_INITIAL']     = batch[8]
output_df['CARRIER_SYSTEM']             = batch[9]
output_df['SERVICE_START_DATE']         = batch[10]
output_df['SERVICE_THRU_DATE']          = batch[11]
output_df['CLAIM_NUMBER']               = batch[12]
output_df['CLAIM_AMOUNT']               = batch[13]
output_df['PROVIDER_NAME']              = batch[14]
output_df['PROVIDER_ADDRESS1']          = batch[15]
output_df['PROVIDER_ADDRESS2']          = batch[16]
output_df['PROVIDER_CITY']              = batch[17]
output_df['PROVIDER_STATE']             = batch[18]
output_df['PROVIDER_ZIP']               = batch[19]
output_df['PROVIDER_COUNTRY']           = batch[20]
output_df['CLAIM_TYPE']                 = batch[21]
output_df['FILE_TYPE']                  = file_name_pattern
output_df['EXPENSE_CATEGORY']           = "vision"


output_df
# Out:
# mapping VSP_FSA_MICHELIN_ to a standard format...
#     EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
# 0         111724631       291446635              MARBAUGH  \
# 1         111724631       276806154                JEWELL
# 2         111724631       301601279             VANVLERAH
# 3         111724631       422027161                   NIX
# 4         111724631       472924762              FLANAGAN
# ..              ...             ...                   ...
# 283       111724631       423316322                  AGEE
# 284       111724631       422478055                 CURRY
# 285       111724631       422927958                BRYANT
# 286       111724631       423212411               REED JR
# 287       111724631       419270798           PRENTICE JR
#
#     PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                    BRETT                             \
# 1                RICHARD D                          D
# 2                  STEVE M                          M
# 3                MICHAEL H                          H
# 4                   JOHN L                          L
# ..                     ...                        ...
# 283                  JAMES                          P
# 284               QUEMONTE                          D
# 285               VERNANDO                          O
# 286                 MELVIN                          A
# 287                 VICTOR                          N
#
#     PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                    19590928          MARBAUGH              BRETT  \
# 1                    19710702            JEWELL           AMANDA J
# 2                    19651014        VAN VLERAH             TAMARA
# 3                    19611109               NIX          MICHAEL H
# 4                    19621021          FLANAGAN        FLORRENDA K
# ..                        ...               ...                ...
# 283                  19840121            BARNES              PIPER
# 284                  19980111             CURRY           QUEMONTE
# 285                  19731025            BRYANT             CORRIE
# 286                  19710302           REED JR             MELVIN
# 287                  19740713          PRENTICE             BOBBIE
#
#     PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...
# 0                                     VSP  ...  \
# 1                                     VSP  ...
# 2                                     VSP  ...
# 3                                     VSP  ...
# 4                                     VSP  ...
# ..                     ...            ...  ...
# 283                                   VSP  ...
# 284                      D            VSP  ...
# 285                                   VSP  ...
# 286                      A            VSP  ...
# 287                      L            VSP  ...
#
#                         PROVIDER_NAME           PROVIDER_ADDRESS1
# 0              WALMART STORES EAST LP            1950 HAVEMANN RD  \
# 1                 Mercer In Sight LLC               321 W Main St
# 2               A Hoffman Enterprises               203 N Main St
# 3           Martin Family Eyecare LLC                925 Mally St
# 4    Aboite Family Eyecare Center Inc       7625 W Jefferson Blvd
# ..                                ...                         ...
# 283                      Ce Bonds LLC  1701 McFarland Blvd E Suit
# 284           Wal Mart Stores East Lp         1501 Skyland Blvd E
# 285         Martin Family Eyecare LLC                925 Mally St
# 286           Wal Mart Stores East Lp         5710 McFarland Blvd
# 287         Martin Family Eyecare LLC                925 Mally St
#
#     PROVIDER_ADDRESS2 PROVIDER_CITY PROVIDER_STATE PROVIDER_ZIP
# 0                            CELINA             OH        45822  \
# 1                          Van Wert             OH        45891
# 2                        Hicksville             OH        43526
# 3                        Tuscaloosa             AL        35405
# 4                        Fort Wayne             IN        46804
# ..                ...           ...            ...          ...
# 283                      Tuscaloosa             AL        35404
# 284                      Tuscaloosa             AL        35405
# 285                      Tuscaloosa             AL        35405
# 286                       Northport             AL        35476
# 287                      Tuscaloosa             AL        35405
#
#     PROVIDER_COUNTRY CLAIM_TYPE          FILE_TYPE EXPENSE_CATEGORY
# 0                 US             VSP_FSA_MICHELIN_           vision
# 1                 US             VSP_FSA_MICHELIN_           vision
# 2                 US             VSP_FSA_MICHELIN_           vision
# 3                 US             VSP_FSA_MICHELIN_           vision
# 4                 US             VSP_FSA_MICHELIN_           vision
# ..               ...        ...                ...              ...
# 283               US             VSP_FSA_MICHELIN_           vision
# 284               US             VSP_FSA_MICHELIN_           vision
# 285               US             VSP_FSA_MICHELIN_           vision
# 286               US             VSP_FSA_MICHELIN_           vision
# 287               US             VSP_FSA_MICHELIN_           vision
#
# [1205 rows x 24 columns]

# %%
def map_Michelin_Union_VSP(batch, file_name_pattern, output_header): 
    
    # creating a data frame with specified output_header
    output_df = pd.DataFrame(columns=output_header, dtype=str)
    # output_df = output_df.astype(str)

    # Filling in DataFrame columns from the batch dataframe 
    output_df['EMPLOYER_TAX_ID']            = batch[0]
    output_df['PARTICIPANT_SSN']            = batch[1]
    output_df['PARTICIPANT_LAST_NAME']      = batch[2]
    output_df['PARTICIPANT_FIRST_NAME']     = batch[3]
    output_df['PARTICIPANT_MIDDLE_INITIAL'] = batch[4]
    output_df['PARTICIPANT_DATE_OF_BIRTH']  = batch[5]
    output_df['PATIENT_LAST_NAME']          = batch[6]
    output_df['PATIENT_FIRST_NAME']         = batch[7]
    output_df['PATIENT_MIDDLE_INITIAL']     = batch[8]
    output_df['CARRIER_SYSTEM']             = batch[9]
    output_df['SERVICE_START_DATE']         = batch[10]
    output_df['SERVICE_THRU_DATE']          = batch[11]
    output_df['CLAIM_NUMBER']               = batch[12]
    output_df['CLAIM_AMOUNT']               = batch[13]
    output_df['PROVIDER_NAME']              = batch[14]
    output_df['PROVIDER_ADDRESS1']          = batch[15]
    output_df['PROVIDER_ADDRESS2']          = batch[16]
    output_df['PROVIDER_CITY']              = batch[17]
    output_df['PROVIDER_STATE']             = batch[18]
    output_df['PROVIDER_ZIP']               = batch[19]
    output_df['PROVIDER_COUNTRY']           = batch[20]
    output_df['CLAIM_TYPE']                 = batch[21]
    output_df['FILE_TYPE']                  = file_name_pattern
    output_df['EXPENSE_CATEGORY']           = "vision"

    return(output_df)

map_Michelin_Union_VSP(batch, file_name_pattern, output_header)
# Out:
#     EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
# 0         111724631       291446635              MARBAUGH  \
# 1         111724631       276806154                JEWELL
# 2         111724631       301601279             VANVLERAH
# 3         111724631       422027161                   NIX
# 4         111724631       472924762              FLANAGAN
# ..              ...             ...                   ...
# 283       111724631       423316322                  AGEE
# 284       111724631       422478055                 CURRY
# 285       111724631       422927958                BRYANT
# 286       111724631       423212411               REED JR
# 287       111724631       419270798           PRENTICE JR
#
#     PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                    BRETT                             \
# 1                RICHARD D                          D
# 2                  STEVE M                          M
# 3                MICHAEL H                          H
# 4                   JOHN L                          L
# ..                     ...                        ...
# 283                  JAMES                          P
# 284               QUEMONTE                          D
# 285               VERNANDO                          O
# 286                 MELVIN                          A
# 287                 VICTOR                          N
#
#     PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                    19590928          MARBAUGH              BRETT  \
# 1                    19710702            JEWELL           AMANDA J
# 2                    19651014        VAN VLERAH             TAMARA
# 3                    19611109               NIX          MICHAEL H
# 4                    19621021          FLANAGAN        FLORRENDA K
# ..                        ...               ...                ...
# 283                  19840121            BARNES              PIPER
# 284                  19980111             CURRY           QUEMONTE
# 285                  19731025            BRYANT             CORRIE
# 286                  19710302           REED JR             MELVIN
# 287                  19740713          PRENTICE             BOBBIE
#
#     PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...
# 0                                     VSP  ...  \
# 1                                     VSP  ...
# 2                                     VSP  ...
# 3                                     VSP  ...
# 4                                     VSP  ...
# ..                     ...            ...  ...
# 283                                   VSP  ...
# 284                      D            VSP  ...
# 285                                   VSP  ...
# 286                      A            VSP  ...
# 287                      L            VSP  ...
#
#                         PROVIDER_NAME           PROVIDER_ADDRESS1
# 0              WALMART STORES EAST LP            1950 HAVEMANN RD  \
# 1                 Mercer In Sight LLC               321 W Main St
# 2               A Hoffman Enterprises               203 N Main St
# 3           Martin Family Eyecare LLC                925 Mally St
# 4    Aboite Family Eyecare Center Inc       7625 W Jefferson Blvd
# ..                                ...                         ...
# 283                      Ce Bonds LLC  1701 McFarland Blvd E Suit
# 284           Wal Mart Stores East Lp         1501 Skyland Blvd E
# 285         Martin Family Eyecare LLC                925 Mally St
# 286           Wal Mart Stores East Lp         5710 McFarland Blvd
# 287         Martin Family Eyecare LLC                925 Mally St
#
#     PROVIDER_ADDRESS2 PROVIDER_CITY PROVIDER_STATE PROVIDER_ZIP
# 0                            CELINA             OH        45822  \
# 1                          Van Wert             OH        45891
# 2                        Hicksville             OH        43526
# 3                        Tuscaloosa             AL        35405
# 4                        Fort Wayne             IN        46804
# ..                ...           ...            ...          ...
# 283                      Tuscaloosa             AL        35404
# 284                      Tuscaloosa             AL        35405
# 285                      Tuscaloosa             AL        35405
# 286                       Northport             AL        35476
# 287                      Tuscaloosa             AL        35405
#
#     PROVIDER_COUNTRY CLAIM_TYPE          FILE_TYPE EXPENSE_CATEGORY
# 0                 US             VSP_FSA_MICHELIN_           vision
# 1                 US             VSP_FSA_MICHELIN_           vision
# 2                 US             VSP_FSA_MICHELIN_           vision
# 3                 US             VSP_FSA_MICHELIN_           vision
# 4                 US             VSP_FSA_MICHELIN_           vision
# ..               ...        ...                ...              ...
# 283               US             VSP_FSA_MICHELIN_           vision
# 284               US             VSP_FSA_MICHELIN_           vision
# 285               US             VSP_FSA_MICHELIN_           vision
# 286               US             VSP_FSA_MICHELIN_           vision
# 287               US             VSP_FSA_MICHELIN_           vision
#
# [1205 rows x 24 columns]

# %%
from module import list_files_date_regx
from module import concat_Michelin_Union_BCBSAL
import pandas as pd
import json 

os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_BCBSAL']['file_input_path']
file_name_pattern = config['Michelin_Union_BCBSAL']['file_name_pattern']
date_start_regx   = config['Michelin_Union_BCBSAL']['date_start_regx']
date_length       = config['Michelin_Union_BCBSAL']['date_length']


batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# reading file... BFG_OPTUM_CLAIMS_20230616.TXT
# reading file... BFG_OPTUM_CLAIMS_20230609.TXT
# reading file... BFG_OPTUM_CLAIMS_20230605.TXT
# reading file... BFG_OPTUM_CLAIMS_20230526.TXT
# reading file... BFG_OPTUM_CLAIMS_20230519.TXT
# reading file... BFG_OPTUM_CLAIMS_20230512.TXT
# reading file... BFG_OPTUM_CLAIMS_202304281.TXT
# reading file... BFG_OPTUM_CLAIMS_20230428.TXT
# reading file... BFG_OPTUM_CLAIMS_20230428_2.TXT
# reading file... BFG_OPTUM_CLAIMS_20230414.TXT
# reading file... BFG_OPTUM_CLAIMS_20230407.TXT
# reading file... BFG_OPTUM_CLAIMS_20230331.TXT
# reading file... BFG_OPTUM_CLAIMS_20230324.TXT
# reading file... BFG_OPTUM_CLAIMS_20230317.TXT
# reading file... BFG_OPTUM_CLAIMS_20230310.TXT
# reading file... BFG_OPTUM_CLAIMS_20230303.TXT
# reading file... BFG_OPTUM_CLAIMS_20230224.TXT
# reading file... BFG_OPTUM_CLAIMS_20230222 (1).TXT
# reading file... BFG_OPTUM_CLAIMS_20230222.TXT
#
# files batched!

# %%
def map_Michelin_Union_BCBSAL(batch, file_name_pattern, output_header): 
    
    # creating a data frame with specified output_header
    output_df = pd.DataFrame(columns=output_header, dtype=str)
    # output_df = output_df.astype(str)

    # Filling in DataFrame columns from the batch dataframe 
    output_df['EMPLOYER_TAX_ID']            = batch[0]
    output_df['PARTICIPANT_SSN']            = batch[1]
    output_df['PARTICIPANT_LAST_NAME']      = batch[2]
    output_df['PARTICIPANT_FIRST_NAME']     = batch[3]
    output_df['PARTICIPANT_MIDDLE_INITIAL'] = batch[4]
    output_df['PARTICIPANT_DATE_OF_BIRTH']  = batch[5]
    output_df['PATIENT_LAST_NAME']          = batch[6]
    output_df['PATIENT_FIRST_NAME']         = batch[7]
    output_df['PATIENT_MIDDLE_INITIAL']     = batch[8]
    output_df['CARRIER_SYSTEM']             = batch[9]
    output_df['SERVICE_START_DATE']         = batch[10]
    output_df['SERVICE_THRU_DATE']          = batch[11]
    output_df['CLAIM_NUMBER']               = batch[12]
    output_df['CLAIM_AMOUNT']               = batch[13]
    output_df['PROVIDER_NAME']              = batch[14]
    output_df['PROVIDER_ADDRESS1']          = batch[15]
    output_df['PROVIDER_ADDRESS2']          = batch[16]
    output_df['PROVIDER_CITY']              = batch[17]
    output_df['PROVIDER_STATE']             = batch[18]
    output_df['PROVIDER_ZIP']               = batch[19]
    output_df['PROVIDER_COUNTRY']           = batch[20]
    output_df['CLAIM_TYPE']                 = ""
    output_df['FILE_TYPE']                  = file_name_pattern
    output_df['EXPENSE_CATEGORY']           = "medical"

    return(output_df)

map_Michelin_Union_BCBSAL(batch, file_name_pattern, output_header)
# Out:
#      EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
# 0          11-172463       632587854                RIZVIC  \
# 1          11-172463       627108964                 YOUNG
# 2          11-172463       627108964                 YOUNG
# 3          11-172463       627108964                 YOUNG
# 4          11-172463       627108964                 YOUNG
# ...              ...             ...                   ...
# 9687       11-172463       424435484               FULGHAM
# 9688       11-172463       422155516                BOLTON
# 9689       11-172463       424040457               ELLIOTT
# 9690       11-172463       514358390               BONILLA
# 9691       11-172463       514358390               BONILLA
#
#      PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                     HARIS                             \
# 1                      OLIN
# 2                      OLIN
# 3                      OLIN
# 4                      OLIN
# ...                     ...                        ...
# 9687                TIMOTHY
# 9688                  JAMES
# 9689                 EDWARD
# 9690                ALFONSO
# 9691                ALFONSO
#
#      PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                     19921218            RIZVIC              HARIS  \
# 1                     19720731         YOUNG III               OLIN
# 2                     19720731         YOUNG III               OLIN
# 3                     19720731         YOUNG III               OLIN
# 4                     19720731         YOUNG III               OLIN
# ...                        ...               ...                ...
# 9687                  19950630           FULGHAM              KAYLA
# 9688                  19670607            HUDSON             AUTUMN
# 9689                  19640417           ELLIOTT             CALLIE
# 9690                  19880801           BONILLA             PENELO
# 9691                  19880801           BONILLA             PENELO
#
#      PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...               PROVIDER_NAME
# 0                                   BCBSAL  ...             LEFFERS KEVIN J  \
# 1                                   BCBSAL  ...  Laboratory Corp Of America
# 2                                   BCBSAL  ...  Laboratory Corp Of America
# 3                                   BCBSAL  ...  Laboratory Corp Of America
# 4                                   BCBSAL  ...  Laboratory Corp Of America
# ...                     ...            ...  ...                         ...
# 9687                                BCBSAL  ...  Laboratory Corp Of America
# 9688                                BCBSAL  ...          MEREDITH M GRAY MD
# 9689                                BCBSAL  ...         BIBB MEDICAL CENTER
# 9690                                BCBSAL  ...               MARTIN BRAD D
# 9691                                BCBSAL  ...               MARTIN BRAD D
#
#      PROVIDER_ADDRESS1 PROVIDER_ADDRESS2 PROVIDER_CITY PROVIDER_STATE
# 0           PO BOX 208                      FORT WAYNE             IN  \
# 1          PO BOX 2270                      BURLINGTON             NC
# 2          PO BOX 2270                      BURLINGTON             NC
# 3          PO BOX 2270                      BURLINGTON             NC
# 4          PO BOX 2270                      BURLINGTON             NC
# ...                ...               ...           ...            ...
# 9687       PO BOX 2270                      BURLINGTON             NC
# 9688  2750 HOSPITAL DR                       NORTHPORT             AL
# 9689      PO BOX 17199                         BELFAST             ME
# 9690  1015 E DUPONT RD                      FORT WAYNE             IN
# 9691  1015 E DUPONT RD                      FORT WAYNE             IN
#
#      PROVIDER_ZIP                                   PROVIDER_COUNTRY
# 0       468010208  US                                            ...  \
# 1       272162270  US                                            ...
# 2       272162270  US                                            ...
# 3       272162270  US                                            ...
# 4       272162270  US                                            ...
# ...           ...                                                ...
# 9687    272162270  US                                            ...
# 9688    354763360  US                                            ...
# 9689    049154066  US                                            ...
# 9690    468251553  US                                            ...
# 9691    468251553  US                                            ...
#
#      CLAIM_TYPE          FILE_TYPE EXPENSE_CATEGORY
# 0                BFG_OPTUM_CLAIMS_          medical
# 1                BFG_OPTUM_CLAIMS_          medical
# 2                BFG_OPTUM_CLAIMS_          medical
# 3                BFG_OPTUM_CLAIMS_          medical
# 4                BFG_OPTUM_CLAIMS_          medical
# ...         ...                ...              ...
# 9687             BFG_OPTUM_CLAIMS_          medical
# 9688             BFG_OPTUM_CLAIMS_          medical
# 9689             BFG_OPTUM_CLAIMS_          medical
# 9690             BFG_OPTUM_CLAIMS_          medical
# 9691             BFG_OPTUM_CLAIMS_          medical
#
# [56562 rows x 24 columns]

# %%
from functions import list_files_date_regx
from functions import concat_Michelin_Union_MedImpact
import os
import pandas as pd
import json 

os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_MedImpact']['file_input_path']
file_name_pattern = config['Michelin_Union_MedImpact']['file_name_pattern']
date_start_regx   = config['Michelin_Union_MedImpact']['date_start_regx']
date_length       = config['Michelin_Union_MedImpact']['date_length']


batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_MedImpact(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MedImpact ...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230612_20230618_202306190102.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230605_20230611_202306120103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230529_20230604_202306050103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230522_20230528_202305290103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230515_20230521_202305220103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230508_20230514_202305150103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230501_20230507_202305080103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230424_20230430_202305010102.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230417_20230423_202304240105.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230410_20230416_202304170103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230403_20230409_202304100104.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230327_20230402_202304030103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230320_20230326_202303270103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230313_20230319_202303200103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230306_20230312_202303130103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230227_20230305_202303060103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230220_20230226_202302270103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230213_20230219_202302200103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230206_20230212_202302130102.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230130_20230205_202302060102.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230123_20230129_202301300103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230116_20230122_202301230107.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230109_20230115_202301160103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230102_20230108_202301090104.dat]...
#
# files batched!

# %%
batch
# Out:
#               0    1 2  3                                4 5  6  7
# 0      1-172463  X          402392153                                \
# 1      1-172463  X          402392153
# 2      1-172463  X          402392153
# 3      1-172463  X          418139537
# 4      1-172463  X          398682804
# ...         ...  ... .. ..                             ... .. .. ..
# 3993   1-172463  X          416157984
# 3994   1-172463  X          423028930
# 3995   1-172463  X          423908729
# 3996   1-172463  X          423908729
# 3997   1-172463  X          302823806
#
#                                                       8
# 0     SMITH                                         ...  \
# 1     SMITH                                         ...
# 2     SMITH                                         ...
# 3     THRASHER                                      ...
# 4     MEISNER                                       ...
# ...                                                 ...
# 3993  MAYFIELD                                      ...
# 3994  DARLING                                       ...
# 3995  MILLER JR                                     ...
# 3996  MILLER JR                                     ...
# 3997  BUELL                                         ...
#
#                                                       9  ...
# 0     CHAD                                          ...  ...  \
# 1     CHAD                                          ...  ...
# 2     CHAD                                          ...  ...
# 3     CATHY                                         ...  ...
# 4     GLENN                                         ...  ...
# ...                                                 ...  ...
# 3993  MEJIAS                                        ...  ...
# 3994  STEPHANIE                                     ...  ...
# 3995  JESSIE                                        ...  ...
# 3996  JESSIE                                        ...  ...
# 3997  HEATH                                         ...  ...
#
#                         23               24
# 0     8652385594            000000000000.00  \
# 1     8652385599            000000000000.00
# 2     8652385604            000000000000.00
# 3     8652385758            000000000021.26
# 4     8652386605            000000000038.45
# ...                    ...              ...
# 3993  8400450757            000000000001.92
# 3994  8400450890            000000000014.74
# 3995  8400450906            000000000085.61
# 3996  8400450936            000000000000.00
# 3997  8400452255            000000000000.00
#
#                                                      25
# 0     WALGREENS #10560                              ...  \
# 1     WALGREENS #10560                              ...
# 2     WALGREENS #10560                              ...
# 3     BIRDI                                         ...
# 4     BIRDI                                         ...
# ...                                                 ...
# 3993  CVS PHARMACY #04835                           ...
# 3994  CVS PHARMACY #04969                           ...
# 3995  CVS PHARMACY #04835                           ...
# 3996  CVS PHARMACY #04835                           ...
# 3997  WALMART PHARMACY 10-1333                      ...
#
#                                                      26
# 0     6620 BARDSTOWN RD                             ...  \
# 1     6620 BARDSTOWN RD                             ...
# 2     6620 BARDSTOWN RD                             ...
# 3     8060 S KYRENE RD                              ...
# 4     8060 S KYRENE RD                              ...
# ...                                                 ...
# 3993  1910 MCFARLAND BLVD                           ...
# 3994  536 HUDSON DRIVE                              ...
# 3995  1910 MCFARLAND BLVD                           ...
# 3996  1910 MCFARLAND BLVD                           ...
# 3997  301 TOWN CENTER BLVD                          ...
#
#                                                      27
# 0                                                   ...  \
# 1                                                   ...
# 2                                                   ...
# 3                                                   ...
# 4                                                   ...
# ...                                                 ...
# 3993                                                ...
# 3994                                                ...
# 3995                                                ...
# 3996                                                ...
# 3997                                                ...
#
#                                                      28  29
# 0     LOUISVILLE                                    ...  KY  \
# 1     LOUISVILLE                                    ...  KY
# 2     LOUISVILLE                                    ...  KY
# 3     TEMPE                                         ...  AZ
# 4     TEMPE                                         ...  AZ
# ...                                                 ...  ..
# 3993  NORTHPORT                                     ...  AL
# 3994  GORDO                                         ...  AL
# 3995  NORTHPORT                                     ...  AL
# 3996  NORTHPORT                                     ...  AL
# 3997  VAN WERT                                      ...  OH
#
#                         30                                                 31
# 0     40291-3045            JEFFERSON                                     ...  \
# 1     40291-3045            JEFFERSON                                     ...
# 2     40291-3045            JEFFERSON                                     ...
# 3     85284-2109            MARICOPA                                      ...
# 4     85284-2109            MARICOPA                                      ...
# ...                    ...                                                ...
# 3993  35476-0000            TUSCALOOSA                                    ...
# 3994  35466-0000            PICKENS                                       ...
# 3995  35476-0000            TUSCALOOSA                                    ...
# 3996  35476-0000            TUSCALOOSA                                    ...
# 3997  45891-0000            VAN WERT                                      ...
#
#                                               FILE_NAME
# 0     type112_mna05_mna09_mna16_t112_nov_optum_20230...
# 1     type112_mna05_mna09_mna16_t112_nov_optum_20230...
# 2     type112_mna05_mna09_mna16_t112_nov_optum_20230...
# 3     type112_mna05_mna09_mna16_t112_nov_optum_20230...
# 4     type112_mna05_mna09_mna16_t112_nov_optum_20230...
# ...                                                 ...
# 3993  type112_mna05_mna09_mna16_t112_nov_optum_20230...
# 3994  type112_mna05_mna09_mna16_t112_nov_optum_20230...
# 3995  type112_mna05_mna09_mna16_t112_nov_optum_20230...
# 3996  type112_mna05_mna09_mna16_t112_nov_optum_20230...
# 3997  type112_mna05_mna09_mna16_t112_nov_optum_20230...
#
# [101518 rows x 33 columns]

# %%
def map_Michelin_Union_MedImpact(batch, output_header): 
    
    # creating a data frame with specified output_header
    output_df = pd.DataFrame(columns=output_header, dtype=str)
    # output_df = output_df.astype(str)

    # Filling in DataFrame columns from the batch dataframe 
    output_df['EMPLOYER_TAX_ID']            = batch[0]
    output_df['PARTICIPANT_SSN']            = batch[4]
    output_df['PARTICIPANT_LAST_NAME']      = batch[8]
    output_df['PARTICIPANT_FIRST_NAME']     = batch[9]
    output_df['PARTICIPANT_MIDDLE_INITIAL'] = batch[14]
    output_df['PARTICIPANT_DATE_OF_BIRTH']  = batch[15]
    output_df['PATIENT_LAST_NAME']          = batch[16]
    output_df['PATIENT_FIRST_NAME']         = batch[18]
    output_df['PATIENT_MIDDLE_INITIAL']     = batch[19]
    output_df['CARRIER_SYSTEM']             = ""
    output_df['SERVICE_START_DATE']         = batch[21]
    output_df['SERVICE_THRU_DATE']          = batch[22]
    output_df['CLAIM_NUMBER']               = batch[20]
    output_df['CLAIM_AMOUNT']               = batch[24]
    output_df['PROVIDER_NAME']              = batch[25]
    output_df['PROVIDER_ADDRESS1']          = batch[26]
    output_df['PROVIDER_ADDRESS2']          = batch[27]
    output_df['PROVIDER_CITY']              = batch[28]
    output_df['PROVIDER_STATE']             = batch[29]
    output_df['PROVIDER_ZIP']               = batch[30]
    output_df['PROVIDER_COUNTRY']           = ""
    output_df['CLAIM_TYPE']                 = ""
    output_df['FILE_NAME']                  = batch['FILE_NAME']
    output_df['EXPENSE_CATEGORY']           = "medical"

    return(output_df)

output_header = config['output']['output_header']
map_Michelin_Union_MedImpact(batch, output_header)
# Out:
#      EMPLOYER_TAX_ID                 PARTICIPANT_SSN
# 0           1-172463  402392153                       \
# 1           1-172463  402392153
# 2           1-172463  402392153
# 3           1-172463  418139537
# 4           1-172463  398682804
# ...              ...                             ...
# 3993        1-172463  416157984
# 3994        1-172463  423028930
# 3995        1-172463  423908729
# 3996        1-172463  423908729
# 3997        1-172463  302823806
#
#                                   PARTICIPANT_LAST_NAME
# 0     SMITH                                         ...  \
# 1     SMITH                                         ...
# 2     SMITH                                         ...
# 3     THRASHER                                      ...
# 4     MEISNER                                       ...
# ...                                                 ...
# 3993  MAYFIELD                                      ...
# 3994  DARLING                                       ...
# 3995  MILLER JR                                     ...
# 3996  MILLER JR                                     ...
# 3997  BUELL                                         ...
#
#                                  PARTICIPANT_FIRST_NAME
# 0     CHAD                                          ...  \
# 1     CHAD                                          ...
# 2     CHAD                                          ...
# 3     CATHY                                         ...
# 4     GLENN                                         ...
# ...                                                 ...
# 3993  MEJIAS                                        ...
# 3994  STEPHANIE                                     ...
# 3995  JESSIE                                        ...
# 3996  JESSIE                                        ...
# 3997  HEATH                                         ...
#
#      PARTICIPANT_MIDDLE_INITIAL PARTICIPANT_DATE_OF_BIRTH
# 0                                                19850206  \
# 1                                                19850206
# 2                                                19850206
# 3                             L                  19661214
# 4                             A                  19570921
# ...                         ...                       ...
# 3993                          J                  19770622
# 3994                          Y                  19700418
# 3995                          L                  19610922
# 3996                          L                  19610922
# 3997                          A                  19830217
#
#                                       PATIENT_LAST_NAME
# 0     SMITH                                         ...  \
# 1     SMITH                                         ...
# 2     SMITH                                         ...
# 3     THRASHER                                      ...
# 4     MEISNER                                       ...
# ...                                                 ...
# 3993  MAYFIELD                                      ...
# 3994  THOMAS                                        ...
# 3995  MILLER                                        ...
# 3996  MILLER                                        ...
# 3997  BUELL                                         ...
#
#                                      PATIENT_FIRST_NAME
# 0     AVA                                           ...  \
# 1     AVA                                           ...
# 2     AVA                                           ...
# 3     CATHY                                         ...
# 4     DEBRA                                         ...
# ...                                                 ...
# 3993  MEJIAS                                        ...
# 3994  CARL                                          ...
# 3995  VALERIE                                       ...
# 3996  VALERIE                                       ...
# 3997  HEATH                                         ...
#
#      PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...
# 0                         R                 ...  \
# 1                         R                 ...
# 2                         R                 ...
# 3                         L                 ...
# 4                                           ...
# ...                     ...            ...  ...
# 3993                      J                 ...
# 3994                      E                 ...
# 3995                                        ...
# 3996                                        ...
# 3997                      A                 ...
#
#                                           PROVIDER_NAME
# 0     WALGREENS #10560                              ...  \
# 1     WALGREENS #10560                              ...
# 2     WALGREENS #10560                              ...
# 3     BIRDI                                         ...
# 4     BIRDI                                         ...
# ...                                                 ...
# 3993  CVS PHARMACY #04835                           ...
# 3994  CVS PHARMACY #04969                           ...
# 3995  CVS PHARMACY #04835                           ...
# 3996  CVS PHARMACY #04835                           ...
# 3997  WALMART PHARMACY 10-1333                      ...
#
#                                       PROVIDER_ADDRESS1
# 0     6620 BARDSTOWN RD                             ...  \
# 1     6620 BARDSTOWN RD                             ...
# 2     6620 BARDSTOWN RD                             ...
# 3     8060 S KYRENE RD                              ...
# 4     8060 S KYRENE RD                              ...
# ...                                                 ...
# 3993  1910 MCFARLAND BLVD                           ...
# 3994  536 HUDSON DRIVE                              ...
# 3995  1910 MCFARLAND BLVD                           ...
# 3996  1910 MCFARLAND BLVD                           ...
# 3997  301 TOWN CENTER BLVD                          ...
#
#                                       PROVIDER_ADDRESS2
# 0                                                   ...  \
# 1                                                   ...
# 2                                                   ...
# 3                                                   ...
# 4                                                   ...
# ...                                                 ...
# 3993                                                ...
# 3994                                                ...
# 3995                                                ...
# 3996                                                ...
# 3997                                                ...
#
#                                           PROVIDER_CITY PROVIDER_STATE
# 0     LOUISVILLE                                    ...             KY  \
# 1     LOUISVILLE                                    ...             KY
# 2     LOUISVILLE                                    ...             KY
# 3     TEMPE                                         ...             AZ
# 4     TEMPE                                         ...             AZ
# ...                                                 ...            ...
# 3993  NORTHPORT                                     ...             AL
# 3994  GORDO                                         ...             AL
# 3995  NORTHPORT                                     ...             AL
# 3996  NORTHPORT                                     ...             AL
# 3997  VAN WERT                                      ...             OH
#
#               PROVIDER_ZIP PROVIDER_COUNTRY CLAIM_TYPE
# 0     40291-3045                                        \
# 1     40291-3045
# 2     40291-3045
# 3     85284-2109
# 4     85284-2109
# ...                    ...              ...        ...
# 3993  35476-0000
# 3994  35466-0000
# 3995  35476-0000
# 3996  35476-0000
# 3997  45891-0000
#
#                                               FILE_NAME EXPENSE_CATEGORY
# 0     type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# 1     type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# 2     type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# 3     type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# 4     type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# ...                                                 ...              ...
# 3993  type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# 3994  type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# 3995  type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# 3996  type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
# 3997  type112_mna05_mna09_mna16_t112_nov_optum_20230...          medical
#
# [101518 rows x 24 columns]

# %%
from functions import list_files_date_regx
from functions import concat_Michelin_Union_Metlife
import os
import pandas as pd
import json 

os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_Metlife']['file_input_path']
file_name_pattern = config['Michelin_Union_Metlife']['file_name_pattern']
date_start_regx   = config['Michelin_Union_Metlife']['date_start_regx']
date_length       = config['Michelin_Union_Metlife']['date_length']


batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_Metlife(file_input_path, file_name_pattern, date_start_regx, date_length)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MetLife ...
# reading file [Optum_metlife_06212023.txt]...
# reading file [Optum_metlife_06142023.txt]...
# reading file [Optum_metlife_06072023.txt]...
# reading file [Optum_metlife_05312023.txt]...
# reading file [Optum_metlife_05242023.txt]...
# reading file [Optum_metlife_05172023.txt]...
# reading file [Optum_metlife_05102023.txt]...
# reading file [Optum_metlife_05032023.txt]...
# reading file [Optum_metlife_04262023.txt]...
# reading file [Optum_metlife_04192023.txt]...
# reading file [Optum_metlife_04122023.txt]...
# reading file [Optum_metlife_04052023.txt]...
# reading file [Optum_metlife_03292023.txt]...
# reading file [Optum_metlife_03222023.txt]...
# reading file [Optum_metlife_03152023.txt]...
# reading file [Optum_metlife_03082023.txt]...
# reading file [Optum_metlife_03012023.txt]...
# reading file [Optum_metlife_02222023.txt]...
# reading file [Optum_metlife_02152023.txt]...
# reading file [Optum_metlife_02082023.txt]...
# reading file [Optum_metlife_02012023.txt]...
# reading file [Optum_metlife_01252023.txt]...
# reading file [Optum_metlife_01182023.txt]...
# reading file [Optum_metlife_01112023.txt]...
# reading file [Optum_metlife_01042023.txt]...
#
# files batched!

# %%
batch.columns
# Out:
# Index(['EMPLOYER_TAX_ID', 'PARTICIPANT_SSN', 'PARTICIPANT_LAST_NAME',
#        'PARTICIPANT_FIRST_NAME', 'PARTICIPANT_MIDDLE_INITIAL',
#        'PARTICIPANT_DATE_OF_BIRTH', 'PATIENT_LAST_NAME', 'PATIENT_FIRST_NAME',
#        'PATIENT_MIDDLE_INITIAL', 'CARRIER_SYSTEM', 'SERVICE_START_DATE',
#        'SERVICE_THRU_DATE', 'CLAIM_NUMBER', 'CLAIM_AMOUNT', 'PROVIDER_NAME',
#        'PROVIDER_ADDRESS1', 'PROVIDER_ADDRESS2', 'PROVIDER_CITY',
#        'PROVIDER_STATE', 'PROVIDER_ZIP', 'PROVIDER_COUNTRY', 'CLAIM_TYPE',
#        'FILE_NAME'],
#       dtype='object')

# %%
import pandas as pd

def map_Michelin_Union_Metlife(batch, output_header): 
    
    # creating a data frame with specified output_header
    output_df = pd.DataFrame(columns=output_header, dtype=str)
    # output_df = output_df.astype(str)

    # Filling in DataFrame columns from the batch dataframe 
    output_df['EMPLOYER_TAX_ID']            = batch['EMPLOYER_TAX_ID']
    output_df['PARTICIPANT_SSN']            = batch['PARTICIPANT_SSN']
    output_df['PARTICIPANT_LAST_NAME']      = batch['PARTICIPANT_LAST_NAME']
    output_df['PARTICIPANT_FIRST_NAME']     = batch['PARTICIPANT_FIRST_NAME']
    output_df['PARTICIPANT_MIDDLE_INITIAL'] = batch['PARTICIPANT_MIDDLE_INITIAL']
    output_df['PARTICIPANT_DATE_OF_BIRTH']  = batch['PARTICIPANT_DATE_OF_BIRTH']
    output_df['PATIENT_LAST_NAME']          = batch['PATIENT_LAST_NAME']
    output_df['PATIENT_FIRST_NAME']         = batch['PATIENT_FIRST_NAME']
    output_df['PATIENT_MIDDLE_INITIAL']     = batch['PATIENT_MIDDLE_INITIAL']
    output_df['CARRIER_SYSTEM']             = batch['CARRIER_SYSTEM']
    output_df['SERVICE_START_DATE']         = batch['SERVICE_START_DATE']
    output_df['SERVICE_THRU_DATE']          = batch['SERVICE_THRU_DATE']
    output_df['CLAIM_NUMBER']               = batch['CLAIM_NUMBER']
    output_df['CLAIM_AMOUNT']               = batch['CLAIM_AMOUNT']
    output_df['PROVIDER_NAME']              = batch['PROVIDER_NAME']
    output_df['PROVIDER_ADDRESS1']          = batch['PROVIDER_ADDRESS1']
    output_df['PROVIDER_ADDRESS2']          = batch['PROVIDER_ADDRESS2']
    output_df['PROVIDER_CITY']              = batch['PROVIDER_CITY']
    output_df['PROVIDER_STATE']             = batch['PROVIDER_STATE']
    output_df['PROVIDER_ZIP']               = batch['PROVIDER_ZIP']
    output_df['PROVIDER_COUNTRY']           = batch['PROVIDER_COUNTRY']
    output_df['CLAIM_TYPE']                 = batch['CLAIM_TYPE']   
    output_df['FILE_NAME']                  = batch['FILE_NAME']
    output_df['EXPENSE_CATEGORY']           = "dental"

    return(output_df)

output_header = config['output']['output_header']
map_Michelin_Union_Metlife(batch, output_header)
# Out:
#                                         EMPLOYER_TAX_ID PARTICIPANT_SSN
# 0                                               2333000       356781763  \
# 1                                               2333000       491921595
# 2                                               2333000       313829632
# 3                                               2333000       648516032
# 4                                               0027919       292748596
# ...                                                 ...             ...
# 3308                                            2665775       615158535
# 3309                                            2665775       624969704
# 3310                                            2665775       772106298
# 3311                                            2665775       840851876
# 3312  0003312T                                      ...
#
#      PARTICIPANT_LAST_NAME PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                   SAUBER                    AMY                             \
# 1                 OCONNELL                   RYAN
# 2                   NORRIS                   MARK
# 3       MANYARI BUSTAMANTE                ERNESTO
# 4                    WEAKS                   TROY
# ...                    ...                    ...                        ...
# 3308                  TING                 ANDREY
# 3309                 ALGAS                JESSICA
# 3310                 SILVA                VALERIA
# 3311                 OLAVE                VALERIA
# 3312
#
#      PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                       082305            SAUBER              KYLIE  \
# 1                       101511          OCONNELL              MAEVE
# 2                       122510            NORRIS             SAYURI
# 3                       021309    MANYARI TORRES       ERNESTO AUGU
# 4                       042700          WEAKS JR               TROY
# ...                        ...               ...                ...
# 3308                    101184              TING             ANDREY
# 3309                    100301             ALGAS           KRISTINA
# 3310                    060473             SILVA            VALERIA
# 3311                    121894             OLAVE
# 3312
#
#      PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...    PROVIDER_NAME
# 0                                        D  ...    BRUCE WARDELL  \
# 1                                        D  ...   CYRUS ALIZADEH
# 2                                        D  ...  VIDYA BETTAGERE
# 3                                        D  ...     JULIE MCCRAY
# 4                                        D  ...  BRANDON PARRISH
# ...                     ...            ...  ...              ...
# 3308                                     D  ...        BRIAN KAR
# 3309                                     D  ...  CHRISTINA MASON
# 3310                                     D  ...   WILLIAM STRUPP
# 3311                                     D  ...  DUSTIN PETERSON
# 3312                                        ...
#
#                   PROVIDER_ADDRESS1               PROVIDER_ADDRESS2
# 0               BRUCE S WARDELL DMD  1000 GRAND CANYON PKWY STE 305  \
# 1          ALIZADEH ORTHODONTICS PC                    PO BOX 30070
# 2               VB ORTHODONTICS LLC                3819 FAIRVIEW DR
# 3               ST LOUIS UNIVERSITY                  3320 RUTGER ST
# 4     INGLEMAN PARRISH ORTHODONTICS                  5215 N BEND DR
# ...                             ...                             ...
# 3308            BRIAN M KAR DMD INC          138 N SAN GABRIEL BLVD
# 3309      CHRISTINA P MASON DDS INC           5433 CLAYTON RD STE D
# 3310     WILLIAM C STRUPP JR DDS PA                906 N BELCHER RD
# 3311              CDB RIO BRAVO LLC   1625 RIO BRAVO BLVD SW STE 33
# 3312
#
#         PROVIDER_CITY PROVIDER_STATE PROVIDER_ZIP PROVIDER_COUNTRY
# 0     HOFFMAN ESTATES             IL   60169-1732               US  \
# 1      SALT LAKE CITY             UT   63017-7321               US
# 2            ANDERSON             IN   46013-4059               US
# 3         SAINT LOUIS             MO   63104-1122               US
# 4          FORT WAYNE             IN   45891-2488               US
# ...               ...            ...          ...              ...
# 3308      SAN GABRIEL             CA   91775-2427               US
# 3309          CLAYTON             CA   94517-1090               US
# 3310       CLEARWATER             FL   33765-2105               US
# 3311      ALBUQUERQUE             NM   87105-6043               US
# 3312
#
#                                              CLAIM_TYPE
# 0                                                   ...  \
# 1                                                   ...
# 2                                                   ...
# 3                                                   ...
# 4                                                   ...
# ...                                                 ...
# 3308                                                ...
# 3309                                                ...
# 3310                                                ...
# 3311                                                ...
# 3312
#
#                        FILE_NAME EXPENSE_CATEGORY
# 0     Optum_metlife_06212023.txt           dental
# 1     Optum_metlife_06212023.txt           dental
# 2     Optum_metlife_06212023.txt           dental
# 3     Optum_metlife_06212023.txt           dental
# 4     Optum_metlife_06212023.txt           dental
# ...                          ...              ...
# 3308  Optum_metlife_01042023.txt           dental
# 3309  Optum_metlife_01042023.txt           dental
# 3310  Optum_metlife_01042023.txt           dental
# 3311  Optum_metlife_01042023.txt           dental
# 3312  Optum_metlife_01042023.txt           dental
#
# [72476 rows x 24 columns]

# %%
from functions import concat_Michelin_Union_VSP
from functions import map_Michelin_Union_VSP
import os
import pandas as pd
import json 

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['Michelin_Union_VSP']['file_input_path']
file_name_pattern = config['Michelin_Union_VSP']['file_name_pattern']
date_start_regx   = config['Michelin_Union_VSP']['date_start_regx']
date_length       = config['Michelin_Union_VSP']['date_length']
output_header      = config['output']['output_header']

batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_VSP(file_input_path, file_name_pattern, date_start_regx, date_length)
map_Michelin_Union_VSP(batch, output_header)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/VSP ...
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230527.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230512.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230428.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230411.txt
# reading file... VSP_FSA_MICHELIN_UNION_05102922_20230403.txt
# reading file... VSP_FSA_MICHELIN_05102922_20230328.txt
# reading file... VSP_FSA_MICHELIN_05102922_20230312.txt
# reading file... VSP_FSA_MICHELIN_05102922_20230228.txt
# reading file... VSP_FSA_MICHELIN_05102922_20230227.txt
#
# files batched!
#     EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
# 0         111724631       291446635              MARBAUGH  \
# 1         111724631       276806154                JEWELL
# 2         111724631       301601279             VANVLERAH
# 3         111724631       422027161                   NIX
# 4         111724631       472924762              FLANAGAN
# ..              ...             ...                   ...
# 283       111724631       423316322                  AGEE
# 284       111724631       422478055                 CURRY
# 285       111724631       422927958                BRYANT
# 286       111724631       423212411               REED JR
# 287       111724631       419270798           PRENTICE JR
#
#     PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                    BRETT                             \
# 1                RICHARD D                          D
# 2                  STEVE M                          M
# 3                MICHAEL H                          H
# 4                   JOHN L                          L
# ..                     ...                        ...
# 283                  JAMES                          P
# 284               QUEMONTE                          D
# 285               VERNANDO                          O
# 286                 MELVIN                          A
# 287                 VICTOR                          N
#
#     PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                    19590928          MARBAUGH              BRETT  \
# 1                    19710702            JEWELL           AMANDA J
# 2                    19651014        VAN VLERAH             TAMARA
# 3                    19611109               NIX          MICHAEL H
# 4                    19621021          FLANAGAN        FLORRENDA K
# ..                        ...               ...                ...
# 283                  19840121            BARNES              PIPER
# 284                  19980111             CURRY           QUEMONTE
# 285                  19731025            BRYANT             CORRIE
# 286                  19710302           REED JR             MELVIN
# 287                  19740713          PRENTICE             BOBBIE
#
#     PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...
# 0                                     VSP  ...  \
# 1                                     VSP  ...
# 2                                     VSP  ...
# 3                                     VSP  ...
# 4                                     VSP  ...
# ..                     ...            ...  ...
# 283                                   VSP  ...
# 284                      D            VSP  ...
# 285                                   VSP  ...
# 286                      A            VSP  ...
# 287                      L            VSP  ...
#
#                         PROVIDER_NAME           PROVIDER_ADDRESS1
# 0              WALMART STORES EAST LP            1950 HAVEMANN RD  \
# 1                 Mercer In Sight LLC               321 W Main St
# 2               A Hoffman Enterprises               203 N Main St
# 3           Martin Family Eyecare LLC                925 Mally St
# 4    Aboite Family Eyecare Center Inc       7625 W Jefferson Blvd
# ..                                ...                         ...
# 283                      Ce Bonds LLC  1701 McFarland Blvd E Suit
# 284           Wal Mart Stores East Lp         1501 Skyland Blvd E
# 285         Martin Family Eyecare LLC                925 Mally St
# 286           Wal Mart Stores East Lp         5710 McFarland Blvd
# 287         Martin Family Eyecare LLC                925 Mally St
#
#     PROVIDER_ADDRESS2 PROVIDER_CITY PROVIDER_STATE PROVIDER_ZIP
# 0                            CELINA             OH        45822  \
# 1                          Van Wert             OH        45891
# 2                        Hicksville             OH        43526
# 3                        Tuscaloosa             AL        35405
# 4                        Fort Wayne             IN        46804
# ..                ...           ...            ...          ...
# 283                      Tuscaloosa             AL        35404
# 284                      Tuscaloosa             AL        35405
# 285                      Tuscaloosa             AL        35405
# 286                       Northport             AL        35476
# 287                      Tuscaloosa             AL        35405
#
#     PROVIDER_COUNTRY CLAIM_TYPE                                     FILE_NAME
# 0                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt  \
# 1                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 2                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 3                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 4                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# ..               ...        ...                                           ...
# 283               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 284               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 285               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 286               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 287               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
#
#     EXPENSE_CATEGORY
# 0             vision
# 1             vision
# 2             vision
# 3             vision
# 4             vision
# ..               ...
# 283           vision
# 284           vision
# 285           vision
# 286           vision
# 287           vision
#
# [1205 rows x 24 columns]

# %%
from dictionary import concat_Michelin_Union_VSP
from dictionary import map_Michelin_Union_VSP
import os
import pandas as pd
import json 

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

carrier = 'VSP'

# storing variables from config.json file 
file_input_path   = config[carrier]['file_input_path']
file_name_pattern = config[carrier]['file_name_pattern']
date_start_regx   = config[carrier]['date_start_regx']
date_length       = config[carrier]['date_length']
output_header      = config['output']['output_header']

batch, file_name_pattern, files_start_dt, files_end_dt = concat[carrier](file_input_path, file_name_pattern, date_start_regx, date_length)

map_Michelin_Union_VSP(batch, output_header)
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/VSP ...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230612.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230527.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230512.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230428.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230411.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230403.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230328.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230312.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230228.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230227.txt]...
#
# files batched!
#     EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
# 0         111724631       291446635              MARBAUGH  \
# 1         111724631       276806154                JEWELL
# 2         111724631       301601279             VANVLERAH
# 3         111724631       422027161                   NIX
# 4         111724631       472924762              FLANAGAN
# ..              ...             ...                   ...
# 283       111724631       423316322                  AGEE
# 284       111724631       422478055                 CURRY
# 285       111724631       422927958                BRYANT
# 286       111724631       423212411               REED JR
# 287       111724631       419270798           PRENTICE JR
#
#     PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                    BRETT                             \
# 1                RICHARD D                          D
# 2                  STEVE M                          M
# 3                MICHAEL H                          H
# 4                   JOHN L                          L
# ..                     ...                        ...
# 283                  JAMES                          P
# 284               QUEMONTE                          D
# 285               VERNANDO                          O
# 286                 MELVIN                          A
# 287                 VICTOR                          N
#
#     PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                    19590928          MARBAUGH              BRETT  \
# 1                    19710702            JEWELL           AMANDA J
# 2                    19651014        VAN VLERAH             TAMARA
# 3                    19611109               NIX          MICHAEL H
# 4                    19621021          FLANAGAN        FLORRENDA K
# ..                        ...               ...                ...
# 283                  19840121            BARNES              PIPER
# 284                  19980111             CURRY           QUEMONTE
# 285                  19731025            BRYANT             CORRIE
# 286                  19710302           REED JR             MELVIN
# 287                  19740713          PRENTICE             BOBBIE
#
#     PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...
# 0                                     VSP  ...  \
# 1                                     VSP  ...
# 2                                     VSP  ...
# 3                                     VSP  ...
# 4                                     VSP  ...
# ..                     ...            ...  ...
# 283                                   VSP  ...
# 284                      D            VSP  ...
# 285                                   VSP  ...
# 286                      A            VSP  ...
# 287                      L            VSP  ...
#
#                         PROVIDER_NAME           PROVIDER_ADDRESS1
# 0              WALMART STORES EAST LP            1950 HAVEMANN RD  \
# 1                 Mercer In Sight LLC               321 W Main St
# 2               A Hoffman Enterprises               203 N Main St
# 3           Martin Family Eyecare LLC                925 Mally St
# 4    Aboite Family Eyecare Center Inc       7625 W Jefferson Blvd
# ..                                ...                         ...
# 283                      Ce Bonds LLC  1701 McFarland Blvd E Suit
# 284           Wal Mart Stores East Lp         1501 Skyland Blvd E
# 285         Martin Family Eyecare LLC                925 Mally St
# 286           Wal Mart Stores East Lp         5710 McFarland Blvd
# 287         Martin Family Eyecare LLC                925 Mally St
#
#     PROVIDER_ADDRESS2 PROVIDER_CITY PROVIDER_STATE PROVIDER_ZIP
# 0                            CELINA             OH        45822  \
# 1                          Van Wert             OH        45891
# 2                        Hicksville             OH        43526
# 3                        Tuscaloosa             AL        35405
# 4                        Fort Wayne             IN        46804
# ..                ...           ...            ...          ...
# 283                      Tuscaloosa             AL        35404
# 284                      Tuscaloosa             AL        35405
# 285                      Tuscaloosa             AL        35405
# 286                       Northport             AL        35476
# 287                      Tuscaloosa             AL        35405
#
#     PROVIDER_COUNTRY CLAIM_TYPE                                     FILE_NAME
# 0                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt  \
# 1                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 2                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 3                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 4                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# ..               ...        ...                                           ...
# 283               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 284               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 285               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 286               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 287               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
#
#     EXPENSE_CATEGORY
# 0             vision
# 1             vision
# 2             vision
# 3             vision
# 4             vision
# ..               ...
# 283           vision
# 284           vision
# 285           vision
# 286           vision
# 287           vision
#
# [1205 rows x 24 columns]

# %%
from dictionary import concat
from dictionary import map
import os
import pandas as pd
import json 

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

def concat_and_map(carrier):
    # open and read config.json file
    with open('config.json', 'r') as config_file: 
        config = json.load(config_file)

    # storing variables from config.json file 
    file_input_path   = config[carrier]['file_input_path']
    file_name_pattern = config[carrier]['file_name_pattern']
    date_start_regx   = config[carrier]['date_start_regx']
    date_length       = config[carrier]['date_length']
    output_header      = config['output']['output_header']

    batch, file_name_pattern, files_start_dt, files_end_dt = concat[carrier](file_input_path, file_name_pattern, date_start_regx, date_length)

    output_df = map_Michelin_Union_VSP(batch, output_header)

    return output_df, files_start_dt, files_end_dt



# define carrier and call functions
carrier = 'VSP'
output_df, files_start_dt, files_end_dt = concat_and_map(carrier)


output_df
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/VSP ...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230612.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230527.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230512.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230428.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230411.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230403.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230328.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230312.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230228.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230227.txt]...
#
# files batched!
#     EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
# 0         111724631       291446635              MARBAUGH  \
# 1         111724631       276806154                JEWELL
# 2         111724631       301601279             VANVLERAH
# 3         111724631       422027161                   NIX
# 4         111724631       472924762              FLANAGAN
# ..              ...             ...                   ...
# 283       111724631       423316322                  AGEE
# 284       111724631       422478055                 CURRY
# 285       111724631       422927958                BRYANT
# 286       111724631       423212411               REED JR
# 287       111724631       419270798           PRENTICE JR
#
#     PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                    BRETT                             \
# 1                RICHARD D                          D
# 2                  STEVE M                          M
# 3                MICHAEL H                          H
# 4                   JOHN L                          L
# ..                     ...                        ...
# 283                  JAMES                          P
# 284               QUEMONTE                          D
# 285               VERNANDO                          O
# 286                 MELVIN                          A
# 287                 VICTOR                          N
#
#     PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                    19590928          MARBAUGH              BRETT  \
# 1                    19710702            JEWELL           AMANDA J
# 2                    19651014        VAN VLERAH             TAMARA
# 3                    19611109               NIX          MICHAEL H
# 4                    19621021          FLANAGAN        FLORRENDA K
# ..                        ...               ...                ...
# 283                  19840121            BARNES              PIPER
# 284                  19980111             CURRY           QUEMONTE
# 285                  19731025            BRYANT             CORRIE
# 286                  19710302           REED JR             MELVIN
# 287                  19740713          PRENTICE             BOBBIE
#
#     PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...
# 0                                     VSP  ...  \
# 1                                     VSP  ...
# 2                                     VSP  ...
# 3                                     VSP  ...
# 4                                     VSP  ...
# ..                     ...            ...  ...
# 283                                   VSP  ...
# 284                      D            VSP  ...
# 285                                   VSP  ...
# 286                      A            VSP  ...
# 287                      L            VSP  ...
#
#                         PROVIDER_NAME           PROVIDER_ADDRESS1
# 0              WALMART STORES EAST LP            1950 HAVEMANN RD  \
# 1                 Mercer In Sight LLC               321 W Main St
# 2               A Hoffman Enterprises               203 N Main St
# 3           Martin Family Eyecare LLC                925 Mally St
# 4    Aboite Family Eyecare Center Inc       7625 W Jefferson Blvd
# ..                                ...                         ...
# 283                      Ce Bonds LLC  1701 McFarland Blvd E Suit
# 284           Wal Mart Stores East Lp         1501 Skyland Blvd E
# 285         Martin Family Eyecare LLC                925 Mally St
# 286           Wal Mart Stores East Lp         5710 McFarland Blvd
# 287         Martin Family Eyecare LLC                925 Mally St
#
#     PROVIDER_ADDRESS2 PROVIDER_CITY PROVIDER_STATE PROVIDER_ZIP
# 0                            CELINA             OH        45822  \
# 1                          Van Wert             OH        45891
# 2                        Hicksville             OH        43526
# 3                        Tuscaloosa             AL        35405
# 4                        Fort Wayne             IN        46804
# ..                ...           ...            ...          ...
# 283                      Tuscaloosa             AL        35404
# 284                      Tuscaloosa             AL        35405
# 285                      Tuscaloosa             AL        35405
# 286                       Northport             AL        35476
# 287                      Tuscaloosa             AL        35405
#
#     PROVIDER_COUNTRY CLAIM_TYPE                                     FILE_NAME
# 0                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt  \
# 1                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 2                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 3                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# 4                 US             VSP_FSA_MICHELIN_UNION_05102922_20230612.txt
# ..               ...        ...                                           ...
# 283               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 284               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 285               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 286               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
# 287               US                   VSP_FSA_MICHELIN_05102922_20230227.txt
#
#     EXPENSE_CATEGORY
# 0             vision
# 1             vision
# 2             vision
# 3             vision
# 4             vision
# ..               ...
# 283           vision
# 284           vision
# 285           vision
# 286           vision
# 287           vision
#
# [1205 rows x 24 columns]

# %%
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

from module import concat_and_map

concat_and_map('BCBSAL')
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# reading file [BFG_OPTUM_CLAIMS_20230616.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230609.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230605.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230526.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230519.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230512.TXT]...
# reading file [BFG_OPTUM_CLAIMS_202304281.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230428.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230428_2.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230414.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230407.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230331.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230324.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230317.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230310.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230303.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230224.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230222 (1).TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230222.TXT]...
#
# files batched!
# (     EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
#  0          11-172463       632587854                RIZVIC  \
#  1          11-172463       627108964                 YOUNG
#  2          11-172463       627108964                 YOUNG
#  3          11-172463       627108964                 YOUNG
#  4          11-172463       627108964                 YOUNG
#  ...              ...             ...                   ...
#  9687       11-172463       424435484               FULGHAM
#  9688       11-172463       422155516                BOLTON
#  9689       11-172463       424040457               ELLIOTT
#  9690       11-172463       514358390               BONILLA
#  9691       11-172463       514358390               BONILLA
#
#       PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
#  0                     HARIS                             \
#  1                      OLIN
#  2                      OLIN
#  3                      OLIN
#  4                      OLIN
#  ...                     ...                        ...
#  9687                TIMOTHY
#  9688                  JAMES
#  9689                 EDWARD
#  9690                ALFONSO
#  9691                ALFONSO
#
#       PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
#  0                     19921218            RIZVIC              HARIS  \
#  1                     19720731         YOUNG III               OLIN
#  2                     19720731         YOUNG III               OLIN
#  3                     19720731         YOUNG III               OLIN
#  4                     19720731         YOUNG III               OLIN
#  ...                        ...               ...                ...
#  9687                  19950630           FULGHAM              KAYLA
#  9688                  19670607            HUDSON             AUTUMN
#  9689                  19640417           ELLIOTT             CALLIE
#  9690                  19880801           BONILLA             PENELO
#  9691                  19880801           BONILLA             PENELO
#
#       PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...               PROVIDER_NAME
#  0                                   BCBSAL  ...             LEFFERS KEVIN J  \
#  1                                   BCBSAL  ...  Laboratory Corp Of America
#  2                                   BCBSAL  ...  Laboratory Corp Of America
#  3                                   BCBSAL  ...  Laboratory Corp Of America
#  4                                   BCBSAL  ...  Laboratory Corp Of America
#  ...                     ...            ...  ...                         ...
#  9687                                BCBSAL  ...  Laboratory Corp Of America
#  9688                                BCBSAL  ...          MEREDITH M GRAY MD
#  9689                                BCBSAL  ...         BIBB MEDICAL CENTER
#  9690                                BCBSAL  ...               MARTIN BRAD D
#  9691                                BCBSAL  ...               MARTIN BRAD D
#
#       PROVIDER_ADDRESS1 PROVIDER_ADDRESS2 PROVIDER_CITY PROVIDER_STATE
#  0           PO BOX 208                      FORT WAYNE             IN  \
#  1          PO BOX 2270                      BURLINGTON             NC
#  2          PO BOX 2270                      BURLINGTON             NC
#  3          PO BOX 2270                      BURLINGTON             NC
#  4          PO BOX 2270                      BURLINGTON             NC
#  ...                ...               ...           ...            ...
#  9687       PO BOX 2270                      BURLINGTON             NC
#  9688  2750 HOSPITAL DR                       NORTHPORT             AL
#  9689      PO BOX 17199                         BELFAST             ME
#  9690  1015 E DUPONT RD                      FORT WAYNE             IN
#  9691  1015 E DUPONT RD                      FORT WAYNE             IN
#
#       PROVIDER_ZIP                                   PROVIDER_COUNTRY
#  0       468010208  US                                            ...  \
#  1       272162270  US                                            ...
#  2       272162270  US                                            ...
#  3       272162270  US                                            ...
#  4       272162270  US                                            ...
#  ...           ...                                                ...
#  9687    272162270  US                                            ...
#  9688    354763360  US                                            ...
#  9689    049154066  US                                            ...
#  9690    468251553  US                                            ...
#  9691    468251553  US                                            ...
#
#       CLAIM_TYPE                      FILE_NAME EXPENSE_CATEGORY
#  0                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  1                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  2                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  3                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  4                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  ...         ...                            ...              ...
#  9687             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#  9688             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#  9689             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#  9690             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#  9691             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#
#  [56562 rows x 24 columns],
#  '20230616',
#  '20230222')

# %%
import json
from module import concat
from module import map 
from module import concat_and_map

carrier = 'VSP'

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config[carrier]['file_input_path']
file_name_pattern = config[carrier]['file_name_pattern']
date_start_regx   = config[carrier]['date_start_regx']
date_length       = config[carrier]['date_length']
output_header     = config['output']['output_header']
output_path       = config['output']['mapped_output_path']  

# calling function from the concat dictionary and saving variables
batch, file_name_pattern, files_start_dt, files_end_dt = concat[carrier](file_input_path, file_name_pattern, date_start_regx, date_length)

# calling function from the map dictionary and saving the output dataframe
output_df = map[carrier](batch, output_header)

# writing a csv file to output path
file_name = carrier + '_mapped_' + files_start_dt + '_to_' + files_end_dt + '.csv'
file_output_path = output_path + '/' + file_name

print(f'\n\nwriting file [{file_name}] to directory: ')
print(output_path)

output_df.to_csv(file_output_path, index = False)
print('\n\nDone!')
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/VSP ...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230612.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230527.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230512.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230428.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230411.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230403.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230328.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230312.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230228.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230227.txt]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [VSP_mapped_20230227_to_20230612.csv] to directory:
# N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped
#
#
# Done!

# %%
import os
import json
from module import concat
from module import map 


os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

from module import concat_and_map

concat_and_map('BCBSAL')
# Out:
# Listing files from directory N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL ...
# reading file [BFG_OPTUM_CLAIMS_20230616.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230609.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230605.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230526.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230519.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230512.TXT]...
# reading file [BFG_OPTUM_CLAIMS_202304281.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230428.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230428_2.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230414.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230407.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230331.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230324.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230317.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230310.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230303.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230224.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230222 (1).TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230222.TXT]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [BCBSAL_mapped_2023-02-22_to_2023-06-16.csv] to directory:
# N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped
#
#
# Done!
# (     EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
#  0          11-172463       632587854                RIZVIC  \
#  1          11-172463       627108964                 YOUNG
#  2          11-172463       627108964                 YOUNG
#  3          11-172463       627108964                 YOUNG
#  4          11-172463       627108964                 YOUNG
#  ...              ...             ...                   ...
#  9687       11-172463       424435484               FULGHAM
#  9688       11-172463       422155516                BOLTON
#  9689       11-172463       424040457               ELLIOTT
#  9690       11-172463       514358390               BONILLA
#  9691       11-172463       514358390               BONILLA
#
#       PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
#  0                     HARIS                             \
#  1                      OLIN
#  2                      OLIN
#  3                      OLIN
#  4                      OLIN
#  ...                     ...                        ...
#  9687                TIMOTHY
#  9688                  JAMES
#  9689                 EDWARD
#  9690                ALFONSO
#  9691                ALFONSO
#
#       PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
#  0                     19921218            RIZVIC              HARIS  \
#  1                     19720731         YOUNG III               OLIN
#  2                     19720731         YOUNG III               OLIN
#  3                     19720731         YOUNG III               OLIN
#  4                     19720731         YOUNG III               OLIN
#  ...                        ...               ...                ...
#  9687                  19950630           FULGHAM              KAYLA
#  9688                  19670607            HUDSON             AUTUMN
#  9689                  19640417           ELLIOTT             CALLIE
#  9690                  19880801           BONILLA             PENELO
#  9691                  19880801           BONILLA             PENELO
#
#       PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...               PROVIDER_NAME
#  0                                   BCBSAL  ...             LEFFERS KEVIN J  \
#  1                                   BCBSAL  ...  Laboratory Corp Of America
#  2                                   BCBSAL  ...  Laboratory Corp Of America
#  3                                   BCBSAL  ...  Laboratory Corp Of America
#  4                                   BCBSAL  ...  Laboratory Corp Of America
#  ...                     ...            ...  ...                         ...
#  9687                                BCBSAL  ...  Laboratory Corp Of America
#  9688                                BCBSAL  ...          MEREDITH M GRAY MD
#  9689                                BCBSAL  ...         BIBB MEDICAL CENTER
#  9690                                BCBSAL  ...               MARTIN BRAD D
#  9691                                BCBSAL  ...               MARTIN BRAD D
#
#       PROVIDER_ADDRESS1 PROVIDER_ADDRESS2 PROVIDER_CITY PROVIDER_STATE
#  0           PO BOX 208                      FORT WAYNE             IN  \
#  1          PO BOX 2270                      BURLINGTON             NC
#  2          PO BOX 2270                      BURLINGTON             NC
#  3          PO BOX 2270                      BURLINGTON             NC
#  4          PO BOX 2270                      BURLINGTON             NC
#  ...                ...               ...           ...            ...
#  9687       PO BOX 2270                      BURLINGTON             NC
#  9688  2750 HOSPITAL DR                       NORTHPORT             AL
#  9689      PO BOX 17199                         BELFAST             ME
#  9690  1015 E DUPONT RD                      FORT WAYNE             IN
#  9691  1015 E DUPONT RD                      FORT WAYNE             IN
#
#       PROVIDER_ZIP                                   PROVIDER_COUNTRY
#  0       468010208  US                                            ...  \
#  1       272162270  US                                            ...
#  2       272162270  US                                            ...
#  3       272162270  US                                            ...
#  4       272162270  US                                            ...
#  ...           ...                                                ...
#  9687    272162270  US                                            ...
#  9688    354763360  US                                            ...
#  9689    049154066  US                                            ...
#  9690    468251553  US                                            ...
#  9691    468251553  US                                            ...
#
#       CLAIM_TYPE                      FILE_NAME EXPENSE_CATEGORY
#  0                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  1                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  2                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  3                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  4                BFG_OPTUM_CLAIMS_20230616.TXT          medical
#  ...         ...                            ...              ...
#  9687             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#  9688             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#  9689             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#  9690             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#  9691             BFG_OPTUM_CLAIMS_20230222.TXT          medical
#
#  [56562 rows x 24 columns],
#  'BCBSAL_mapped_2023-02-22_to_2023-06-16.csv')

# %%
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

for key, value in config.items():
    print(f"Key: {key}, Value: {value}")
# Out:
# Key: BCBSAL, Value: {'file_input_path': 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL', 'file_name_pattern': 'BFG_OPTUM_CLAIMS_', 'date_start_regx': 'BFG_OPTUM_CLAIMS_', 'date_length': 8, 'date_format': '%Y%m%d'}
# Key: MedImpact, Value: {'file_input_path': 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MedImpact', 'file_name_pattern': 'type112_mna05_mna09_mna16_t112_nov_optum_', 'date_start_regx': 'type112_mna05_mna09_mna16_t112_nov_optum_', 'date_length': 8, 'date_format': '%Y%m%d'}
# Key: Metlife, Value: {'file_input_path': 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MetLife', 'file_name_pattern': 'Optum_metlife_', 'date_start_regx': 'Optum_metlife_', 'date_length': 8, 'date_format': '%m%d%Y'}
# Key: VSP, Value: {'file_input_path': 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/VSP', 'file_name_pattern': 'VSP_FSA_MICHELIN_', 'date_start_regx': 'VSP_FSA_MICHELIN_(UNION_)?05102922_', 'date_length': 8, 'date_format': '%Y%m%d'}
# Key: output, Value: {'mapped_output_path': 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped', 'output_header': ['EMPLOYER_TAX_ID', 'PARTICIPANT_SSN', 'PARTICIPANT_LAST_NAME', 'PARTICIPANT_FIRST_NAME', 'PARTICIPANT_MIDDLE_INITIAL', 'PARTICIPANT_DATE_OF_BIRTH', 'PATIENT_LAST_NAME', 'PATIENT_FIRST_NAME', 'PATIENT_MIDDLE_INITIAL', 'CARRIER_SYSTEM', 'SERVICE_START_DATE', 'SERVICE_THRU_DATE', 'CLAIM_NUMBER', 'CLAIM_AMOUNT', 'PROVIDER_NAME', 'PROVIDER_ADDRESS1', 'PROVIDER_ADDRESS2', 'PROVIDER_CITY', 'PROVIDER_STATE', 'PROVIDER_ZIP', 'PROVIDER_COUNTRY', 'CLAIM_TYPE', 'FILE_NAME', 'EXPENSE_CATEGORY']}
# Key: app, Value: {'app_path': 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped'}

# %%
from module import list_files_date_regx
import pandas as pd
import json
import os 



# reading config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# saving variables from the json file
input_path = config['output']['mapped_output_path'] 
file_name_pattern = '(.*)(_mapped_)(.*)(_to_)'
date_start_regx = '(.*)(_mapped_)(.*)(_to_)'
date_length = 10

# listing files from the directory
file_list_df = list_files_date_regx(input_path, file_name_pattern, date_start_regx, date_length)

# creating empty dataframe 
batch = pd.DataFrame()

# iterating through list of files
for f in file_list_df['file_list']:

    # retrieving the base file name for logging
    fName = os.path.basename(f)
    print(f"reading file [{fName}]...")

    # reading data frame
    df = pd.read_csv(f, 
            delimiter = ',',
            skiprows = 0, 
            header = 0, 
            dtype = str,
            # encoding= 'unicode_escape'
            )
    
    # removing NAs
    df.fillna('', inplace=True)
    
    # concating rows to the batch dataframe
    batch = pd.concat([batch, df])


print(f"\nfiles batched!")
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped] ...
# reading file [Metlife_mapped_2023-01-04_to_2023-06-21.csv]...
# reading file [VSP_mapped_2023-02-27_to_2023-06-12.csv]...
# reading file [MedImpact_mapped_2023-01-02_to_2023-06-12.csv]...
# reading file [BCBSAL_mapped_2023-02-22_to_2023-06-16.csv]...
#
# files batched!

# %%
def batch_carrier_files(): 
    
    # reading config.json file
    with open('config.json', 'r') as config_file: 
        config = json.load(config_file)

    # saving variables from the json file
    input_path = config['output']['mapped_output_path'] 
    file_name_pattern = '(.*)(_mapped_)(.*)(_to_)'
    date_start_regx = '(.*)(_mapped_)(.*)(_to_)'
    date_length = 10

    # listing files from the directory
    file_list_df = list_files_date_regx(input_path, file_name_pattern, date_start_regx, date_length)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        # retrieving the base file name for logging
        fName = os.path.basename(f)
        print(f"reading file [{fName}]...")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = ',',
                skiprows = 0, 
                header = 0, 
                dtype = str,
                # encoding= 'unicode_escape'
                )

        # removing NAs
        df.fillna('', inplace=True)

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    return(batch)

batch = batch_carrier_files()
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped] ...
# reading file [Metlife_mapped_2023-01-04_to_2023-06-21.csv]...
# reading file [VSP_mapped_2023-02-27_to_2023-06-12.csv]...
# reading file [MedImpact_mapped_2023-01-02_to_2023-06-12.csv]...
# reading file [BCBSAL_mapped_2023-02-22_to_2023-06-16.csv]...
#
# files batched!

# %%
batch
# Out:
#       EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
# 0             2333000       356781763                SAUBER  \
# 1             2333000       491921595              OCONNELL
# 2             2333000       313829632                NORRIS
# 3             2333000       648516032    MANYARI BUSTAMANTE
# 4             0027919       292748596                 WEAKS
# ...               ...             ...                   ...
# 56557       11-172463       424435484               FULGHAM
# 56558       11-172463       422155516                BOLTON
# 56559       11-172463       424040457               ELLIOTT
# 56560       11-172463       514358390               BONILLA
# 56561       11-172463       514358390               BONILLA
#
#       PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                        AMY                             \
# 1                       RYAN
# 2                       MARK
# 3                    ERNESTO
# 4                       TROY
# ...                      ...                        ...
# 56557                TIMOTHY
# 56558                  JAMES
# 56559                 EDWARD
# 56560                ALFONSO
# 56561                ALFONSO
#
#       PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                        082305            SAUBER              KYLIE  \
# 1                        101511          OCONNELL              MAEVE
# 2                        122510            NORRIS             SAYURI
# 3                        021309    MANYARI TORRES       ERNESTO AUGU
# 4                        042700          WEAKS JR               TROY
# ...                         ...               ...                ...
# 56557                  19950630           FULGHAM              KAYLA
# 56558                  19670607            HUDSON             AUTUMN
# 56559                  19640417           ELLIOTT             CALLIE
# 56560                  19880801           BONILLA             PENELO
# 56561                  19880801           BONILLA             PENELO
#
#       PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...               PROVIDER_NAME
# 0                                         D  ...               BRUCE WARDELL  \
# 1                                         D  ...              CYRUS ALIZADEH
# 2                                         D  ...             VIDYA BETTAGERE
# 3                                         D  ...                JULIE MCCRAY
# 4                                         D  ...             BRANDON PARRISH
# ...                      ...            ...  ...                         ...
# 56557                                BCBSAL  ...  Laboratory Corp Of America
# 56558                                BCBSAL  ...          MEREDITH M GRAY MD
# 56559                                BCBSAL  ...         BIBB MEDICAL CENTER
# 56560                                BCBSAL  ...               MARTIN BRAD D
# 56561                                BCBSAL  ...               MARTIN BRAD D
#
#                    PROVIDER_ADDRESS1               PROVIDER_ADDRESS2
# 0                BRUCE S WARDELL DMD  1000 GRAND CANYON PKWY STE 305  \
# 1           ALIZADEH ORTHODONTICS PC                    PO BOX 30070
# 2                VB ORTHODONTICS LLC                3819 FAIRVIEW DR
# 3                ST LOUIS UNIVERSITY                  3320 RUTGER ST
# 4      INGLEMAN PARRISH ORTHODONTICS                  5215 N BEND DR
# ...                              ...                             ...
# 56557                    PO BOX 2270
# 56558               2750 HOSPITAL DR
# 56559                   PO BOX 17199
# 56560               1015 E DUPONT RD
# 56561               1015 E DUPONT RD
#
#          PROVIDER_CITY PROVIDER_STATE PROVIDER_ZIP
# 0      HOFFMAN ESTATES             IL   60169-1732  \
# 1       SALT LAKE CITY             UT   63017-7321
# 2             ANDERSON             IN   46013-4059
# 3          SAINT LOUIS             MO   63104-1122
# 4           FORT WAYNE             IN   45891-2488
# ...                ...            ...          ...
# 56557       BURLINGTON             NC    272162270
# 56558        NORTHPORT             AL    354763360
# 56559          BELFAST             ME    049154066
# 56560       FORT WAYNE             IN    468251553
# 56561       FORT WAYNE             IN    468251553
#
#                                         PROVIDER_COUNTRY
# 0                                                     US  \
# 1                                                     US
# 2                                                     US
# 3                                                     US
# 4                                                     US
# ...                                                  ...
# 56557  US                                            ...
# 56558  US                                            ...
# 56559  US                                            ...
# 56560  US                                            ...
# 56561  US                                            ...
#
#                                               CLAIM_TYPE
# 0                                                    ...  \
# 1                                                    ...
# 2                                                    ...
# 3                                                    ...
# 4                                                    ...
# ...                                                  ...
# 56557
# 56558
# 56559
# 56560
# 56561
#
#                            FILE_NAME EXPENSE_CATEGORY
# 0         Optum_metlife_06212023.txt           dental
# 1         Optum_metlife_06212023.txt           dental
# 2         Optum_metlife_06212023.txt           dental
# 3         Optum_metlife_06212023.txt           dental
# 4         Optum_metlife_06212023.txt           dental
# ...                              ...              ...
# 56557  BFG_OPTUM_CLAIMS_20230222.TXT          medical
# 56558  BFG_OPTUM_CLAIMS_20230222.TXT          medical
# 56559  BFG_OPTUM_CLAIMS_20230222.TXT          medical
# 56560  BFG_OPTUM_CLAIMS_20230222.TXT          medical
# 56561  BFG_OPTUM_CLAIMS_20230222.TXT          medical
#
# [217797 rows x 24 columns]

# %%
pd.pivot_table(batch, values = 'CLAIM_AMOUNT', columns = 'EXPENSE_CATEGORY', aggfunc='sum', fill_value=0)
# Out:
# EXPENSE_CATEGORY                                             dental
# CLAIM_AMOUNT      00001560{00002060{00001940{00001440{00001460{0...  \
#
# EXPENSE_CATEGORY                                            medical
# CLAIM_AMOUNT      000000000000.00000000000000.00000000000000.000...  \
#
# EXPENSE_CATEGORY                                             vision
# CLAIM_AMOUNT      99.44722.60374.20280.20.00107.20.00.00240.40.0...

# %%
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

from module import concat_and_map

map, fname = concat_and_map('VSP')
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/VSP] ...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230612.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230527.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230512.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230428.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230411.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230403.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230328.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230312.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230228.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230227.txt]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [VSP_mapped_2023-02-27_to_2023-06-12.csv] to directory:
# [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped]...
#
#
# Done!

# %%
# converting claim_amount to numeric 
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')
from module import concat_and_map

map, fname = concat_and_map('VSP')
# map['CLAIM_AMOUNT'] = pd.to_numeric(map['CLAIM_AMOUNT'])

print(sum(map['CLAIM_AMOUNT']))
map['CLAIM_AMOUNT']
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/VSP] ...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230612.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230527.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230512.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230428.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230411.txt]...
# reading file [VSP_FSA_MICHELIN_UNION_05102922_20230403.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230328.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230312.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230228.txt]...
# reading file [VSP_FSA_MICHELIN_05102922_20230227.txt]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [VSP_mapped_2023-02-27_to_2023-06-12.csv] to directory:
# [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped]...
#
#
# Done!
# 91586.5599999999
# 0       99.44
# 1      722.60
# 2      374.20
# 3      280.20
# 4        0.00
#         ...
# 283     34.00
# 284     83.00
# 285      0.00
# 286     46.00
# 287      0.00
# Name: CLAIM_AMOUNT, Length: 1205, dtype: float64

# %%
# converting claim_amount to numeric 
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')
from module import concat_and_map

map, fname = concat_and_map('BCBSAL')


# map['CLAIM_AMOUNT'] = pd.to_numeric(map['CLAIM_AMOUNT'])

# print(sum(map['CLAIM_AMOUNT']))
# map['CLAIM_AMOUNT']
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL] ...
# reading file [BFG_OPTUM_CLAIMS_20230616.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230609.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230605.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230526.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230519.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230512.TXT]...
# reading file [BFG_OPTUM_CLAIMS_202304281.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230428.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230428_2.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230414.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230407.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230331.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230324.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230317.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230310.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230303.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230224.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230222 (1).TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230222.TXT]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [BCBSAL_mapped_2023-02-22_to_2023-06-16.csv] to directory:
# [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped]...
#
#
# Done!

# %%
map['CLAIM_AMOUNT'] = pd.to_numeric(map['CLAIM_AMOUNT'])

print(sum(map['CLAIM_AMOUNT']))
map['CLAIM_AMOUNT']
# Out:
# 930601.9599999983
# 0       30.00
# 1       25.24
# 2        9.56
# 3        8.16
# 4        5.78
#         ...
# 9687     2.00
# 9688     5.76
# 9689    31.23
# 9690    30.00
# 9691    30.00
# Name: CLAIM_AMOUNT, Length: 56562, dtype: float64

# %%
# converting claim_amount to numeric 
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')
from module import concat_and_map

map, fname = concat_and_map('MedImpact')


# map['CLAIM_AMOUNT'] = pd.to_numeric(map['CLAIM_AMOUNT'])

# print(sum(map['CLAIM_AMOUNT']))
# map['CLAIM_AMOUNT']
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MedImpact] ...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230612_20230618_202306190102.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230605_20230611_202306120103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230529_20230604_202306050103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230522_20230528_202305290103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230515_20230521_202305220103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230508_20230514_202305150103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230501_20230507_202305080103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230424_20230430_202305010102.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230417_20230423_202304240105.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230410_20230416_202304170103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230403_20230409_202304100104.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230327_20230402_202304030103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230320_20230326_202303270103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230313_20230319_202303200103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230306_20230312_202303130103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230227_20230305_202303060103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230220_20230226_202302270103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230213_20230219_202302200103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230206_20230212_202302130102.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230130_20230205_202302060102.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230123_20230129_202301300103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230116_20230122_202301230107.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230109_20230115_202301160103.dat]...
# reading file [type112_mna05_mna09_mna16_t112_nov_optum_20230102_20230108_202301090104.dat]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [MedImpact_mapped_2023-01-02_to_2023-06-12.csv] to directory:
# [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped]...
#
#
# Done!

# %%
import pandas as pd
pd.to_numeric(map['CLAIM_AMOUNT'])
# Out:
# 0        0.00
# 1        0.00
# 2        0.00
# 3       21.26
# 4       38.45
#         ...
# 3993     1.92
# 3994    14.74
# 3995    85.61
# 3996     0.00
# 3997     0.00
# Name: CLAIM_AMOUNT, Length: 101518, dtype: float64

# %%
# converting claim_amount to numeric 
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')
from module import concat_and_map

map, fname = concat_and_map('Metlife')


# map['CLAIM_AMOUNT'] = pd.to_numeric(map['CLAIM_AMOUNT'])

# print(sum(map['CLAIM_AMOUNT']))
# map['CLAIM_AMOUNT']
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MetLife] ...
# reading file [Optum_metlife_06212023.txt]...
# reading file [Optum_metlife_06142023.txt]...
# reading file [Optum_metlife_06072023.txt]...
# reading file [Optum_metlife_05312023.txt]...
# reading file [Optum_metlife_05242023.txt]...
# reading file [Optum_metlife_05172023.txt]...
# reading file [Optum_metlife_05102023.txt]...
# reading file [Optum_metlife_05032023.txt]...
# reading file [Optum_metlife_04262023.txt]...
# reading file [Optum_metlife_04192023.txt]...
# reading file [Optum_metlife_04122023.txt]...
# reading file [Optum_metlife_04052023.txt]...
# reading file [Optum_metlife_03292023.txt]...
# reading file [Optum_metlife_03222023.txt]...
# reading file [Optum_metlife_03152023.txt]...
# reading file [Optum_metlife_03082023.txt]...
# reading file [Optum_metlife_03012023.txt]...
# reading file [Optum_metlife_02222023.txt]...
# reading file [Optum_metlife_02152023.txt]...
# reading file [Optum_metlife_02082023.txt]...
# reading file [Optum_metlife_02012023.txt]...
# reading file [Optum_metlife_01252023.txt]...
# reading file [Optum_metlife_01182023.txt]...
# reading file [Optum_metlife_01112023.txt]...
# reading file [Optum_metlife_01042023.txt]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [Metlife_mapped_2023-01-04_to_2023-06-21.csv] to directory:
# [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped]...
#
#
# Done!

# %%
map['CLAIM_AMOUNT']
map['CLAIM_AMOUNT'].str.replace('{','')
pd.to_numeric(map['CLAIM_AMOUNT'].str.replace('{',''))

# error in line 96 "00006084B"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "00006084B"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 5
#       2 map['CLAIM_AMOUNT'].str.replace('{','')
#       4 # error in line 96
# ----> 5 pd.to_numeric(map['CLAIM_AMOUNT'].str.replace('{',''))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
#     221         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     222         or isinstance(values_dtype, StringDtype),
#     223     )
#     224 except (ValueError, TypeError):
#     225     if errors == "raise":
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\lib.pyx:2322, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "00006084B" at position 96

# %%
map['CLAIM_AMOUNT']

map['CLAIM_AMOUNT'] = pd.to_numeric(map['CLAIM_AMOUNT'].str[:-1])
map['CLAIM_AMOUNT'] / 100
# Out:
# 0       15.6
# 1       20.6
# 2       19.4
# 3       14.4
# 4       14.6
#         ...
# 3308     8.6
# 3309     2.0
# 3310    18.0
# 3311    13.3
# 3312     NaN
# Name: CLAIM_AMOUNT, Length: 72476, dtype: float64

# %%
# converting claim_amount to numeric 
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')
from module import concat_and_map

map, fname = concat_and_map('Metlife')
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MetLife] ...
# reading file [Optum_metlife_06212023.txt]...
# reading file [Optum_metlife_06142023.txt]...
# reading file [Optum_metlife_06072023.txt]...
# reading file [Optum_metlife_05312023.txt]...
# reading file [Optum_metlife_05242023.txt]...
# reading file [Optum_metlife_05172023.txt]...
# reading file [Optum_metlife_05102023.txt]...
# reading file [Optum_metlife_05032023.txt]...
# reading file [Optum_metlife_04262023.txt]...
# reading file [Optum_metlife_04192023.txt]...
# reading file [Optum_metlife_04122023.txt]...
# reading file [Optum_metlife_04052023.txt]...
# reading file [Optum_metlife_03292023.txt]...
# reading file [Optum_metlife_03222023.txt]...
# reading file [Optum_metlife_03152023.txt]...
# reading file [Optum_metlife_03082023.txt]...
# reading file [Optum_metlife_03012023.txt]...
# reading file [Optum_metlife_02222023.txt]...
# reading file [Optum_metlife_02152023.txt]...
# reading file [Optum_metlife_02082023.txt]...
# reading file [Optum_metlife_02012023.txt]...
# reading file [Optum_metlife_01252023.txt]...
# reading file [Optum_metlife_01182023.txt]...
# reading file [Optum_metlife_01112023.txt]...
# reading file [Optum_metlife_01042023.txt]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [Metlife_mapped_2023-01-04_to_2023-06-21.csv] to directory:
# [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped]...
#
#
# Done!

# %%
map['CLAIM_AMOUNT']
# Out:
# 0       15.6
# 1       20.6
# 2       19.4
# 3       14.4
# 4       14.6
#         ...
# 3308     8.6
# 3309     2.0
# 3310    18.0
# 3311    13.3
# 3312     NaN
# Name: CLAIM_AMOUNT, Length: 72476, dtype: float64

# %%
from module import list_files_date_regx
import pandas as pd
import json
import os 

def batch_carrier_files(): 
    
    # reading config.json file
    with open('config.json', 'r') as config_file: 
        config = json.load(config_file)

    # saving variables from the json file
    input_path = config['output']['mapped_output_path'] 
    file_name_pattern = '(.*)(_mapped_)(.*)(_to_)'
    date_start_regx = '(.*)(_mapped_)(.*)(_to_)'
    date_length = 10

    # listing files from the directory
    file_list_df = list_files_date_regx(input_path, file_name_pattern, date_start_regx, date_length)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        # retrieving the base file name for logging
        fName = os.path.basename(f)
        print(f"reading file [{fName}]...")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = ',',
                skiprows = 0, 
                header = 0, 
                dtype = str,
                # encoding= 'unicode_escape'
                )

        # removing NAs
        df.fillna('', inplace=True)

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    return(batch)

batch = batch_carrier_files()
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped] ...
# reading file [Metlife_mapped_2023-01-04_to_2023-06-21.csv]...
# reading file [VSP_mapped_2023-02-27_to_2023-06-12.csv]...
# reading file [MedImpact_mapped_2023-01-02_to_2023-06-12.csv]...
# reading file [BCBSAL_mapped_2023-02-22_to_2023-06-16.csv]...
#
# files batched!

# %%
# creating a pivot table for the 

batch['CLAIM_AMOUNT'] = pd.to_numeric(batch['CLAIM_AMOUNT'])


carrier_pivot = pd.pivot_table(batch, values = 'CLAIM_AMOUNT', columns = 'EXPENSE_CATEGORY', index='PARTICIPANT_SSN', aggfunc='sum', fill_value=0) 
carrier_pivot
# Out:
# EXPENSE_CATEGORY  dental  medical  vision
# PARTICIPANT_SSN
#                     0.00      0.0     0.0
# 001542296           9.27      0.0     0.0
# 001546238           8.86      0.0     0.0
# 001558948          14.14      0.0     0.0
# 001611317           3.00      0.0     0.0
# ...                  ...      ...     ...
# 899017973          24.00      0.0     0.0
# 899247586           8.30      0.0     0.0
# 899497693          23.90      0.0     0.0
# 899548471          53.27      0.0     0.0
# 899667627           3.10      0.0     0.0
#
# [32771 rows x 3 columns]

# %%
def pivot_carrier_files(): 

    # batching carrier files
    batch = batch_carrier_files()

    # converting to numeric
    batch['CLAIM_AMOUNT'] = pd.to_numeric(batch['CLAIM_AMOUNT'])

    # creating the pivot table 
    carrier_pivot = pd.pivot_table(batch, 
                                   values = 'CLAIM_AMOUNT', 
                                   columns = 'EXPENSE_CATEGORY', 
                                   index='PARTICIPANT_SSN', 
                                   aggfunc='sum', 
                                   fill_value=0) 
    
    return(carrier_pivot)


pivot_carrier_files()
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped] ...
# reading file [Metlife_mapped_2023-01-04_to_2023-06-21.csv]...
# reading file [VSP_mapped_2023-02-27_to_2023-06-12.csv]...
# reading file [MedImpact_mapped_2023-01-02_to_2023-06-12.csv]...
# reading file [BCBSAL_mapped_2023-02-22_to_2023-06-16.csv]...
#
# files batched!
# EXPENSE_CATEGORY  dental  medical  vision
# PARTICIPANT_SSN
#                     0.00      0.0     0.0
# 001542296           9.27      0.0     0.0
# 001546238           8.86      0.0     0.0
# 001558948          14.14      0.0     0.0
# 001611317           3.00      0.0     0.0
# ...                  ...      ...     ...
# 899017973          24.00      0.0     0.0
# 899247586           8.30      0.0     0.0
# 899497693          23.90      0.0     0.0
# 899548471          53.27      0.0     0.0
# 899667627           3.10      0.0     0.0
#
# [32771 rows x 3 columns]

# %%
import os
from module import list_files_date_regx
from module import concat_Michelin_Union_BCBSAL
import pandas as pd
import json 

os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['BCBSAL']['file_input_path']
file_name_pattern = config['BCBSAL']['file_name_pattern']
date_start_regx   = config['BCBSAL']['date_start_regx']
date_length       = config['BCBSAL']['date_length']
date_format       = config['BCBSAL']['date_format']


batch, file_name_pattern, files_start_dt, files_end_dt = concat_Michelin_Union_BCBSAL(file_input_path, file_name_pattern, date_start_regx, date_length, date_format)
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/BCBSAL] ...
# reading file [BFG_OPTUM_CLAIMS_20231009.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230929.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230922.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230915.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230908.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230901.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230825.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230818.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230811.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230804.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230728.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230721.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230717.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230707.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230630.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230623.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230616.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230609.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230605.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230526.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230519.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230512.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230428.TXT]...
# reading file [BFG_OPTUM_CLAIMS_202304281.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230428_2.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230414.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230407.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230331.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230324.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230317.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230310.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230303.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230224.TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230222 (1).TXT]...
# reading file [BFG_OPTUM_CLAIMS_20230222.TXT]...
#
# files batched!

# %%
from module import map_Michelin_Union_BCBSAL
import os
import pandas as pd
import json 

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
output_header     = config['output']['output_header']

map = map_Michelin_Union_BCBSAL(batch, output_header)
map
# Out:
# mapping file to standard format...
#      EMPLOYER_TAX_ID PARTICIPANT_SSN PARTICIPANT_LAST_NAME
# 0          11-172463       590345813                 LANGE  \
# 1          11-172463       595948560                INGRAM
# 2          11-172463       619314166               GAMARRA
# 3          11-172463       424193513                CORLEY
# 4          11-172463       054747900            MONTGOMERY
# ...              ...             ...                   ...
# 9687       11-172463       424435484               FULGHAM
# 9688       11-172463       422155516                BOLTON
# 9689       11-172463       424040457               ELLIOTT
# 9690       11-172463       514358390               BONILLA
# 9691       11-172463       514358390               BONILLA
#
#      PARTICIPANT_FIRST_NAME PARTICIPANT_MIDDLE_INITIAL
# 0                   MICHAEL                             \
# 1                      EARL
# 2                      OMAR
# 3                      GARY
# 4               CHRISTOPHER
# ...                     ...                        ...
# 9687                TIMOTHY
# 9688                  JAMES
# 9689                 EDWARD
# 9690                ALFONSO
# 9691                ALFONSO
#
#      PARTICIPANT_DATE_OF_BIRTH PATIENT_LAST_NAME PATIENT_FIRST_NAME
# 0                     19671216             LANGE              SUSAN  \
# 1                     19871212           PICKETT             ALEXAN
# 2                     19650831           GAMARRA               OMAR
# 3                     19710916            CORLEY             LAUREN
# 4                     19820703        MONTGOMERY             CHRIST
# ...                        ...               ...                ...
# 9687                  19950630           FULGHAM              KAYLA
# 9688                  19670607            HUDSON             AUTUMN
# 9689                  19640417           ELLIOTT             CALLIE
# 9690                  19880801           BONILLA             PENELO
# 9691                  19880801           BONILLA             PENELO
#
#      PATIENT_MIDDLE_INITIAL CARRIER_SYSTEM  ...               PROVIDER_NAME
# 0                                   BCBSAL  ...              CRASE EDWARD C  \
# 1                                   BCBSAL  ...   CHARLES L TORGERSON II MD
# 2                                   BCBSAL  ...               WELCH DEREK C
# 3                                   BCBSAL  ...       KATHERINE W GRELLE MD
# 4                                   BCBSAL  ...             JOHN D TUTEN MD
# ...                     ...            ...  ...                         ...
# 9687                                BCBSAL  ...  Laboratory Corp Of America
# 9688                                BCBSAL  ...          MEREDITH M GRAY MD
# 9689                                BCBSAL  ...         BIBB MEDICAL CENTER
# 9690                                BCBSAL  ...               MARTIN BRAD D
# 9691                                BCBSAL  ...               MARTIN BRAD D
#
#                   PROVIDER_ADDRESS1 PROVIDER_ADDRESS2 PROVIDER_CITY
# 0                     PO BOX 950121                      LOUISVILLE  \
# 1          PO BOX 11407 DRAWER 2335                      BIRMINGHAM
# 2            1010 AIRPARK CENTER DR                       NASHVILLE
# 3     1800 MCFARLAND BLVD N STE 150                      TUSCALOOSA
# 4               3909 MCFARLAND BLVD                       NORTHPORT
# ...                             ...               ...           ...
# 9687                    PO BOX 2270                      BURLINGTON
# 9688               2750 HOSPITAL DR                       NORTHPORT
# 9689                   PO BOX 17199                         BELFAST
# 9690               1015 E DUPONT RD                      FORT WAYNE
# 9691               1015 E DUPONT RD                      FORT WAYNE
#
#      PROVIDER_STATE PROVIDER_ZIP
# 0                KY    402950121  \
# 1                AL    352462335
# 2                TN    372175200
# 3                AL    354062178
# 4                AL    354762838
# ...             ...          ...
# 9687             NC    272162270
# 9688             AL    354763360
# 9689             ME    049154066
# 9690             IN    468251553
# 9691             IN    468251553
#
#                                        PROVIDER_COUNTRY CLAIM_TYPE
# 0     US                                            ...             \
# 1     US                                            ...
# 2     US                                            ...
# 3     US                                            ...
# 4     US                                            ...
# ...                                                 ...        ...
# 9687  US                                            ...
# 9688  US                                            ...
# 9689  US                                            ...
# 9690  US                                            ...
# 9691  US                                            ...
#
#                           FILE_NAME EXPENSE_CATEGORY
# 0     BFG_OPTUM_CLAIMS_20231009.TXT          medical
# 1     BFG_OPTUM_CLAIMS_20231009.TXT          medical
# 2     BFG_OPTUM_CLAIMS_20231009.TXT          medical
# 3     BFG_OPTUM_CLAIMS_20231009.TXT          medical
# 4     BFG_OPTUM_CLAIMS_20231009.TXT          medical
# ...                             ...              ...
# 9687  BFG_OPTUM_CLAIMS_20230222.TXT          medical
# 9688  BFG_OPTUM_CLAIMS_20230222.TXT          medical
# 9689  BFG_OPTUM_CLAIMS_20230222.TXT          medical
# 9690  BFG_OPTUM_CLAIMS_20230222.TXT          medical
# 9691  BFG_OPTUM_CLAIMS_20230222.TXT          medical
#
# [87689 rows x 24 columns]

# %%
import json 
import os 
from module import * 


def batch_carrier_files(): 
    
    # reading config.json file
    with open('config.json', 'r') as config_file: 
        config = json.load(config_file)

    # saving variables from the json file
    input_path = config['output']['mapped_output_path'] 
    file_name_pattern = '(.*)(_mapped_)(.*)(_to_)'
    date_start_regx = '(.*)(_mapped_)(.*)(_to_)'
    date_length = 10

    # listing files from the directory
    file_list_df = list_files_date_regx(input_path, file_name_pattern, date_start_regx, date_length)

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        # retrieving the base file name for logging
        fName = os.path.basename(f)
        print(f"reading file [{fName}]...")

        # reading data frame
        df = pd.read_csv(f, 
                delimiter = ',',
                skiprows = 0, 
                header = 0, 
                dtype = str,
                # encoding= 'unicode_escape'
                )

        # removing NAs
        df.fillna('', inplace=True)

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])
    

    print(f"\nfiles batched!")
    return(batch)

batch = batch_carrier_files()
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped] ...
# reading file [VSP_mapped_2023-02-27_to_2023-09-28.csv]...
# reading file [MedImpact_mapped_2023-01-01_to_2023-01-01.csv]...
# reading file [Metlife_mapped_2023-01-04_to_2023-06-21.csv]...
# reading file [BCBSAL_mapped_2023-02-22_to_2023-10-09.csv]...
#
# files batched!

# %%
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')
from module import pivot_carrier_files

pivot_table = pivot_carrier_files()

print(pivot_table)
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped] ...
# reading file [Metlife_mapped_2023-01-04_to_2023-10-11.csv]...
# reading file [VSP_mapped_2023-02-27_to_2023-09-28.csv]...
# reading file [MedImpact_mapped_2023-01-01_to_2023-01-01.csv]...
# reading file [Metlife_mapped_2023-01-04_to_2023-06-21.csv]...
# reading file [BCBSAL_mapped_2023-02-22_to_2023-10-09.csv]...
#
# files batched!
# EXPENSE_CATEGORY  dental  medical  pharmacy  vision
# PARTICIPANT_SSN
#                     0.00      0.0       0.0     0.0
# 001542296          24.67      0.0       0.0     0.0
# 001546238         134.78      0.0       0.0     0.0
# 001558948          31.62      0.0       0.0     0.0
# 001611317           6.00      0.0       0.0     0.0
# ...                  ...      ...       ...     ...
# 899247586          16.60      0.0       0.0     0.0
# 899497693         314.74      0.0       0.0     0.0
# 899548471         106.54      0.0       0.0     0.0
# 899667627           6.20      0.0       0.0     0.0
# 899741715           6.40      0.0       0.0     0.0
#
# [38978 rows x 4 columns]

# %%
from datetime import date
file_name = f'carrier_pivot_table_{date.today()}.csv'

print(file_name)
# Out:
# carrier_pivot_table_2023-10-23.csv

# %%
from datetime import date
import pandas as pd
from module import *

output_path = 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/pivot/'

# file name with today's date
file_name = f'carrier_pivot_table_{date.today()}.csv'

# full file path name
file_output_path = output_path + file_name


print(f'\n\nwriting file [{file_name}] to directory: ')
print(f'[{output_path}]...')


pivot_table = pivot_carrier_files()
pivot_table.to_csv(file_output_path, index = True)
# Out:
# writing file [carrier_pivot_table_2023-10-23.csv] to directory:
# [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/pivot/]...
#
#
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped] ...
# reading file [Metlife_mapped_2023-01-04_to_2023-10-11.csv]...
# reading file [VSP_mapped_2023-02-27_to_2023-09-28.csv]...
# reading file [MedImpact_mapped_2023-01-01_to_2023-01-01.csv]...
# reading file [Metlife_mapped_2023-01-04_to_2023-06-21.csv]...
# reading file [BCBSAL_mapped_2023-02-22_to_2023-10-09.csv]...
#
# files batched!

# %% [markdown]
# # Pivot table for Wex report
#
# - get recent file
# - categorize expenses
# - create pivot table

# %%
from module import *
import pandas as pd

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

# storing variables from config.json file 
file_input_path   = config['pivot']['file_input_path']
file_name_pattern = config['pivot']['file_name_pattern']
date_start_regx   = config['pivot']['date_start_regx']
date_length       = config['pivot']['date_length']
date_format       = config['pivot']['date_format']


# listing files
file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
file_list_df['file_dates'] = pd.to_datetime(file_list_df['file_dates'], format = date_format)     # converting dates 
file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)                      # sorting 

# find the most recent file uploaded
f = file_list_df["file_list"][0]

# reading data frame
df = pd.read_csv(f, 
        delimiter = ',',
        skiprows = 0, 
        header = None, 
        dtype = str
        )
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/substantiate_claims] ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 17
#      13 date_format       = config['pivot']['date_format']
#      16 # listing files
# ---> 17 file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
#      18 file_list_df['file_dates'] = pd.to_datetime(file_list_df['file_dates'], format = date_format)     # converting dates
#      19 file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)                      # sorting
#
# File c:\Users\nwebb19\python\Michelin_Union_Carrier_Files_py\module.py:16, in list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
#      11 # setting the working directory to file_input_path
#      12 # os.chdir(file_input_path)
#      13
#      14 # listing files from the directory that match file_name_pattern
#      15 file_list = []
# ---> 16 for f in os.listdir(file_input_path):
#      17     if re.search(file_name_pattern, f):
#      18
#      19         # getting absolute path and converting to raw string
#      20         fpath = file_input_path + '/' + f
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/substantiate_claims'

# %%
from module import *
pivot_unsub = pivot_wex_report('unsub')
pivot_autosub = pivot_wex_report('auto')
pivot_carrier = pivot_carrier_files()

# %% [markdown]
# # creating a dictionary to reference the read.file() block of code

# %%
import os
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

from module import concat_and_map

map, fname = concat_and_map('Metlife')
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MetLife] ...
# reading file [Optum_metlife_10112023.txt]...
# reading file [Optum_metlife_10042023.txt]...
# reading file [Optum_metlife_09272023.txt]...
# reading file [Optum_metlife_09202023.txt]...
# reading file [Optum_metlife_09132023.txt]...
# reading file [Optum_metlife_09062023.txt]...
# reading file [Optum_metlife_08302023.txt]...
# reading file [Optum_metlife_08232023.txt]...
# reading file [Optum_metlife_08162023.txt]...
# reading file [Optum_metlife_08092023.txt]...
# reading file [Optum_metlife_08022023.txt]...
# reading file [Optum_metlife_07262023.txt]...
# reading file [Optum_metlife_07192023.txt]...
# reading file [Optum_metlife_07122023.txt]...
# reading file [Optum_metlife_07062023.txt]...
# reading file [Optum_metlife_06282023.txt]...
# reading file [Optum_metlife_06212023.txt]...
# reading file [Optum_metlife_06142023.txt]...
# reading file [Optum_metlife_06072023.txt]...
# reading file [Optum_metlife_05312023.txt]...
# reading file [Optum_metlife_05242023.txt]...
# reading file [Optum_metlife_05172023.txt]...
# reading file [Optum_metlife_05102023.txt]...
# reading file [Optum_metlife_05032023.txt]...
# reading file [Optum_metlife_04262023.txt]...
# reading file [Optum_metlife_04192023.txt]...
# reading file [Optum_metlife_04122023.txt]...
# reading file [Optum_metlife_04052023.txt]...
# reading file [Optum_metlife_03292023.txt]...
# reading file [Optum_metlife_03222023.txt]...
# reading file [Optum_metlife_03152023.txt]...
# reading file [Optum_metlife_03082023.txt]...
# reading file [Optum_metlife_03012023.txt]...
# reading file [Optum_metlife_02222023.txt]...
# reading file [Optum_metlife_02152023.txt]...
# reading file [Optum_metlife_02082023.txt]...
# reading file [Optum_metlife_02012023.txt]...
# reading file [Optum_metlife_01252023.txt]...
# reading file [Optum_metlife_01182023.txt]...
# reading file [Optum_metlife_01112023.txt]...
# reading file [Optum_metlife_01042023.txt]...
#
# files batched!
#
#
# mapping file to standard format...
#
#
# writing file [Metlife_mapped_2023-01-04_to_2023-10-11.csv] to directory:
# [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/carrier_combined/mapped]...
#
#
# Done!

# %%
code_block = """
def greet(name): 
    print("Hello, " + name + "!")
"""

# create a dictionary to store this code 
code_dict = {
    'greet_function': code_block
}

# access the code
saved_code = code_dict['greet_function']

# %%
def read_Michelin_Union_BCBSAL(f):

    # reading data frame
    df = pd.read_csv(f, 
            delimiter = '|',
            skiprows = 0, 
            header = None, 
            dtype = str
            )
    return(df)

def read_Michelin_Union_MedImpact(f):

    # reading data frame
    df = pd.read_csv(f, 
        delimiter = '|',
        skiprows = 0, 
        header = None, 
        dtype = str
        )
    return(df)

def read_Michelin_Union_Metlife(f):

    # reading data frame
    df = pd.read_csv(f, 
        delimiter = '|',
        skiprows = 1, 
        header = 0, 
        dtype = str,
        encoding= 'unicode_escape'
        )
    return(df)

def read_Michelin_Union_VSP(f):

    # reading data frame
    df = pd.read_csv(f, 
        delimiter = ',',
        skiprows = 0, 
        header = None, 
        dtype = str,
        # encoding= 'unicode_escape'
        )
    return(df)


read_file = {
    'BCBSAL': read_Michelin_Union_BCBSAL,
    'MedImpact': read_Michelin_Union_MedImpact, 
    'Metlife': read_Michelin_Union_Metlife, 
    'VSP': read_Michelin_Union_VSP, 
}

def concat_carrier(carrier, file_input_path, file_name_pattern, date_start_regx, date_length, date_format):

    # listing files
    file_list_df = list_files_date_regx(file_input_path, file_name_pattern, date_start_regx, date_length)
    file_list_df['file_dates'] = pd.to_datetime(file_list_df['file_dates'], format = date_format)     # converting dates 
    file_list_df = file_list_df.sort_values(by='file_dates', ascending=False)                      # sorting 

    # creating empty dataframe 
    batch = pd.DataFrame()

    # iterating through list of files
    for f in file_list_df['file_list']:

        # retrieving the base file name for logging
        fName = os.path.basename(f)

        print(f"reading file [{fName}]...")

        # read file from using the stored function
        df = read_file[carrier](f)

        # removing NAs
        df.fillna('', inplace=True)

        # adding file_name column
        df['FILE_NAME'] = fName

        # concating rows to the batch dataframe
        batch = pd.concat([batch, df])

    print(f"\nfiles batched!")

    # getting date range from the list of files within the folder (selecting the first 10 characters only)
    files_end_dt = str(file_list_df.iloc[0,1])[:10]
    files_start_dt = str(file_list_df.iloc[-1,1])[:10]

    # returning variables 
    return(batch, file_name_pattern, files_start_dt, files_end_dt)

# %%
from module import *

# changing working directory to the client folder
os.chdir('C:\\Users\\nwebb19\\python\\Michelin_Union_Carrier_Files_py')

# open and read config.json file
with open('config.json', 'r') as config_file: 
    config = json.load(config_file)

carrier = "Metlife"

# storing variables from config.json file 
file_input_path   = config[carrier]['file_input_path']
file_name_pattern = config[carrier]['file_name_pattern']
date_start_regx   = config[carrier]['date_start_regx']
date_length       = config[carrier]['date_length']
date_format       = config[carrier]['date_format']
output_header      = config['output']['output_header']

batch, file_name_pattern, files_start_dt, files_end_dt = concat_carrier(carrier, file_input_path, file_name_pattern, date_start_regx, date_length, date_format)
# Out:
# Listing files from directory [N:/OPTClaimsConversion/Incoming/OHFSIncoming/OHFSArchive/Michelin Union/MetLife] ...
# reading file [Optum_metlife_10112023.txt]...
# reading file [Optum_metlife_10042023.txt]...
# reading file [Optum_metlife_09272023.txt]...
# reading file [Optum_metlife_09202023.txt]...
# reading file [Optum_metlife_09132023.txt]...
# reading file [Optum_metlife_09062023.txt]...
# reading file [Optum_metlife_08302023.txt]...
# reading file [Optum_metlife_08232023.txt]...
# reading file [Optum_metlife_08162023.txt]...
# reading file [Optum_metlife_08092023.txt]...
# reading file [Optum_metlife_08022023.txt]...
# reading file [Optum_metlife_07262023.txt]...
# reading file [Optum_metlife_07192023.txt]...
# reading file [Optum_metlife_07122023.txt]...
# reading file [Optum_metlife_07062023.txt]...
# reading file [Optum_metlife_06282023.txt]...
# reading file [Optum_metlife_06212023.txt]...
# reading file [Optum_metlife_06142023.txt]...
# reading file [Optum_metlife_06072023.txt]...
# reading file [Optum_metlife_05312023.txt]...
# reading file [Optum_metlife_05242023.txt]...
# reading file [Optum_metlife_05172023.txt]...
# reading file [Optum_metlife_05102023.txt]...
# reading file [Optum_metlife_05032023.txt]...
# reading file [Optum_metlife_04262023.txt]...
# reading file [Optum_metlife_04192023.txt]...
# reading file [Optum_metlife_04122023.txt]...
# reading file [Optum_metlife_04052023.txt]...
# reading file [Optum_metlife_03292023.txt]...
# reading file [Optum_metlife_03222023.txt]...
# reading file [Optum_metlife_03152023.txt]...
# reading file [Optum_metlife_03082023.txt]...
# reading file [Optum_metlife_03012023.txt]...
# reading file [Optum_metlife_02222023.txt]...
# reading file [Optum_metlife_02152023.txt]...
# reading file [Optum_metlife_02082023.txt]...
# reading file [Optum_metlife_02012023.txt]...
# reading file [Optum_metlife_01252023.txt]...
# reading file [Optum_metlife_01182023.txt]...
# reading file [Optum_metlife_01112023.txt]...
# reading file [Optum_metlife_01042023.txt]...
#
# files batched!
